# %%
token='XXXXXX'

# %%
import bitly_api
c = bitly_api.Connection(access_token=token)
c

# %%
results = c.search( 'trayvon', offset=0, limit=1000000)
len(results)
# Out:
# 130

# %%
dates = ([ result['initial'] for result in results ])
dates.sort()
dates[0:10]
# Out:
# [u'20131007170037',
#  u'20131013143735',
#  u'20131014145806',
#  u'20131015155614',
#  u'20131016012914',
#  u'20131016014136',
#  u'20131016043917',
#  u'20131017224413',
#  u'20131018141043',
#  u'20131018202502']

# %%
c.clicks_by_day(shortUrl=results[0]['aggregate_link'] )
# Out:
# [{u'clicks': [{u'clicks': 1, u'day_start': 1382500800},
#    {u'clicks': 7, u'day_start': 1382414400},
#    {u'clicks': 7, u'day_start': 1382328000},
#    {u'clicks': 7, u'day_start': 1382241600},
#    {u'clicks': 10, u'day_start': 1382155200},
#    {u'clicks': 63, u'day_start': 1382068800},
#    {u'clicks': 0, u'day_start': 1381982400}],
#   u'global_hash': u'1cC18Q3',
#   u'short_url': u'http://bit.ly/1cC18Q3',
#   u'user_hash': u'1cC18Q3'}]

# %%
dates
# Out:
# [u'20131007170037',
#  u'20131013143735',
#  u'20131014145806',
#  u'20131015155614',
#  u'20131016012914',
#  u'20131016014136',
#  u'20131016043917',
#  u'20131017224413',
#  u'20131018141043',
#  u'20131018202502',
#  u'20131019014405',
#  u'20131019050237',
#  u'20131019172858',
#  u'20131020152948',
#  u'20131021010331',
#  u'20131021032004',
#  u'20131021044534',
#  u'20131021141546',
#  u'20131021141655',
#  u'20131021150547',
#  u'20131021151804',
#  u'20131021160157',
#  u'20131021160431',
#  u'20131021181513',
#  u'20131021194937',
#  u'20131021235840',
#  u'20131022015658',
#  u'20131022022316',
#  u'20131022043748',
#  u'20131022052452',
#  u'20131022112110',
#  u'20131022140132',
#  u'20131022143623',
#  u'20131022163027',
#  u'20131022164635',
#  u'20131022173807',
#  u'20131022175840',
#  u'20131022181031',
#  u'20131022185844',
#  u'20131022191945',
#  u'20131022192336',
#  u'20131022192413',
#  u'20131022194901',
#  u'20131022195031',
#  u'20131022201153',
# ...
