# %% [markdown]
# This notebook is intended enable testing and evaluation of various extractor methods such as:
#
# * Heuristic Extractor
# * CRF Extractor
# * boilerpipe

# %%
import cPickle
import os.path

api_key = cPickle.load( file( os.path.expanduser( '~/mediacloud_api_key.pickle' ), 'r' ) )

# %%
import cPickle
import os.path

cPickle.dump( api_key, file( os.path.expanduser( '~/mediacloud_api_key.pickle' ), 'wb' ) )

# %%
import sys
sys.path.append('../../foreign_modules/python/')

# %%
loc_key = 'f66a50230d54afaf18822808aed649f1d6ca72b08fb06d5efb6247afe9fbae52'

# %%
import mediacloud, requests, csv, sys, os, json, cPickle

def get_download( downloads_id ):
    download = requests.get('https://api.mediacloud.org/api/v2/downloads/single/'+str(downloads_id)+'?key='+api_key)
    return download.json()[0]

def extract_story( preprocessed_lines, title, description, extractor_method ):
    extract_params = {'key':loc_key, 'preprocessed_lines':preprocessed_lines, 
                           'story_title':title, 'story_description':description, 'extractor_method': extractor_method}
    
    extract_result = requests.put('http://0:3000/api/v2/extractlines/extract',data=json.dumps(extract_params), 
                                headers = {'Content-type': 'application/json'})
    
    extract_result.raise_for_status()
    return extract_result.json()

def get_story_lines( raw_content ):
    story_lines_params = {'key':loc_key, 'body_html':raw_content }
    headers = {'Content-type': 'application/json'}
    story_lines = requests.put('http://0:3000/api/v2/extractlines/story_lines',data=json.dumps(story_lines_params), 
                               params={ 'key': loc_key },headers=headers)
    
    story_lines.raise_for_status()
    
    return story_lines

# %%
import subprocess
import tempfile
import codecs
import time
from lxml import html

#download = get_download( downloads_id )
#raw_content = download[u'raw_content']

def extract_with_boilerpipe( raw_content ):
    with tempfile.NamedTemporaryFile( suffix='.html', delete=False ) as t:
        #print t.name
    
        UTF8Writer = codecs.getwriter('utf8')
        t.file = UTF8Writer(t.file)
        t.file.write( raw_content )
    
        t.close()
        time.sleep( 2 )
        print "original article tmp file ", t.name
        
        #input_file = '/tmp/416655019.htm'
        input_file = t.name
        
        output_tmp = tempfile.NamedTemporaryFile( suffix='.html', delete=False )
        
        output_file = output_tmp.name
        #output_file = '/tmp/highlighted.html'
        print output_file
        print subprocess.check_output(['java', '-jar',
                               '/home/dlarochelle/dev_scratch/boilerpipe_test/out/artifacts/boilerpipe_test_jar/boilerpipe_test.jar',
                               input_file, output_file ] )
        f = open( output_file, 'rb' )
        
        annotated_file_str = f.read()
        
        #t.unlink( t.name )
        output_tmp.close()
        #output_tmp.unlink( output_tmp.name )
        
    return annotated_file_str

# %%
import readability

def extract_with_python_readability( raw_content ):
    doc = readability.Document( raw_content )
    
    return [ doc.short_title(),
             doc.summary() ]

# %%
import goose

def extract_with_python_goose( raw_content ):
    g = goose.Goose()
    
    r = g.extract( raw_html=raw_content )
    return [r.title, r.cleaned_text ]

# %%
import justext

# %%
import operator

def get_extractor_training_text( downloads_id, preprocessed_lines ):
    extractor_training_lines_result = requests.get(
                                                   'https://api.mediacloud.org/api/v2/extractlines/extractor_training_lines/' + str(downloads_id),
                                               headers = {'Content-type': 'application/json'}
                                               , params= {'key': api_key}
                                               )

    extractor_training_lines_result.raise_for_status()

    extractor_training_lines_result = extractor_training_lines_result.json()
    
    line_numbers = [ x['line_number'] for x in extractor_training_lines_result ]
    
    line_numbers = sorted(line_numbers)
    
    line_numbers.sort()
    
    print line_numbers
    
    return operator.itemgetter( * line_numbers )( preprocessed_lines  )

import operator

def get_extracted_text( extractor_results ):
    included_line_numbers = extractor_results['included_line_numbers']
    print included_line_numbers
    
    dl = extractor_results['download_lines']
   
    if len( included_line_numbers ) == 0:
        return []
    else:    
        return operator.itemgetter( * extractor_results['included_line_numbers']   )(dl)

# %%
def html_strip( str ):
    if str == ' ':
        return u' '
    
    try:
        return html.fromstring(str).text_content()    
    except:
        print "Unexpected error on string '" + str + "'" , sys.exc_info()[0]
        #raise
        return u''
    
    

def clean_for_comparison( str ):
    if len(str) > 0:
        ret = html_strip( str )
    else:
        return str
    
    if len(ret) > 0:
        ret = ret.strip()
    
    return ret

# %%
import Levenshtein

def lines_to_comparable_text( lines ):
    text = " ".join([ clean_for_comparison(line) for line in lines ])
    
    if text == '':
        text = u''
        
    return text

def compare_accuracy( lines, lines_expected ):
    return Levenshtein.distance( lines_to_comparable_text( lines ) , lines_to_comparable_text( lines_expected ) )

# %%
def get_anncestors( element ):
    anncestors = [ element ];
    anncestor = element.getparent()
    
    while anncestor != None :
        #print 'loop'
        anncestors.append( anncestor )
        anncestor = anncestor.getparent()
        
    return anncestors

# %%
def text_from_lxml_object( obj):
    if type(obj) is etree._ElementStringResult:
        return u'' + obj
    if type(obj) ==  etree._ElementUnicodeResult:
        return u'' + obj 
    else:
        try:
            return etree.tostring( obj , method='text', encoding="UTF-8") 
        except:
            print type(obj)
            print obj
            
            raise ''

# %%
from lxml import etree

downloads_id =  582817308 
download = get_download( downloads_id )
raw_content = download[ 'raw_content' ]
with open( '/tmp/' + str(downloads_id) , 'wb' ) as f:
    f.write( raw_content )

# %%
def text_children( element):
    ret =  [ t for t in element.xpath("//text()" ) if t.getparent() == element ]
    assert len( ret ) <= 2
    
    if len( ret ) == 2:
        assert ret[0].is_text
        assert ret[1].is_tail
    
    for r in ret:
        if r.is_text:
            assert element.text == r
        else:
            assert r.is_tail
            assert element.tail == r
            
    return ret

# %%
start_container[ annotation['start_offset']: annotation['end_offset'] + 1 ]
# Out:
# "U.S. Senate Democrats blast Obama's migrant family detentions"

# %%
def get_annotated_text( raw_content, annotation):

    htmlparser = etree.HTMLParser()
    root = etree.fromstring( raw_content, htmlparser )
    
    #print annotation[ 'start_xpath' ]
    
    start_container = root.xpath( annotation[ 'start_xpath' ] )[0]
    end_container   = root.xpath( annotation[ 'end_xpath' ] )[0]
    
    if ( start_container == end_container ):
        return [start_container[ annotation['start_offset']: annotation['end_offset'] + 1 ]]
    
        
    if start_container.getparent() == end_container.getparent():
        common_parent = start_container.getparent()
        assert start_container.is_text
        assert end_container.is_tail
        assert common_parent.text == start_container
        assert common_parent.tail == end_container
        
        return [start_container[ annotation['start_offset']:], end_container[ : annotation['end_offset'] + 1 ]]

    
    start_anncestors = get_anncestors( start_container )
    end_anncestors   = get_anncestors( end_container )
    
    print 'sc', start_container
    print 'ec', end_container
    print 'common'
    
    middle_contents = []
    
    p = start_container.getparent()
    prev_p = start_container
    
    if start_container.is_text:
        # append the tail
        texts = text_children( start_container.getparent() )
        if len( texts ) == 2:
            assert texts[1].is_tail
            middle_contents.append( texts[1] )
                                   
    
    while p not in end_anncestors:
        #print "parent:", p, "\n", etree.tostring( p )
        assert p in start_anncestors
        if prev_p != start_container:
            child_index = p.index( prev_p )
            if (child_index + 1) < len( list( p )):
                el = list(p)[ child_index + 1]
            else:
                el = None
                #print "stripping previous parent is the last child of curparrent"
        else:
            el = None
    
        while (el not in end_anncestors) and (el != None) :
            #print "inner loop"
            #print el
            #print etree.tostring( el )
            middle_contents.append( el )
            el = el.getnext()
            
        print "end inner loop"
        prev_p = p
        p = p.getparent()
    
    print "end loop"
    
    print p
    commonanncestors = list([ s for s in start_anncestors if s in end_anncestors ] )
    
    assert p in commonanncestors
    commonanncestor = commonanncestors[0]
    
    print commonanncestors
    print start_container == end_container
    assert p == commonanncestor
    
    print "commonacccestor", commonanncestor 
    #print etree.tostring( commonanncestor )
       
    processed_children = [ c for c in list (commonanncestor) if c in start_anncestors ]
    print "ca's processed children"
    #print processed_children
    #print [ etree.tostring( c ) + "\n" for c in list( commonanncestor ) ] 
    assert( len( processed_children ) == 1 )
    processed_child = processed_children[ 0]
    
    el = processed_child.getnext()
    
    print "start True"
    while True:
        
            print 'outer loop:',  el, "\n", etree.tostring( el )
                    
            while (el not in end_anncestors):
                print "inner loop"
                #print el
                #print etree.tostring( el )
                middle_contents.append( el )
                el = el.getnext()
                
            print 'end inner loop'
            
            # element is an ancester of end_container and has no (non-text)children
            # since end_container is text el must be it's parent so we can stop
            if (len(list(el)) == 0 ):
                            
                print 'found end_contain parent, exiting loop:',  el, "\n", etree.tostring( el )
                
                assert end_container in text_children(el)
    
                assert end_container.getparent() == el
                break
            
            ## HACK bc/ lxml/etree doesn't have a real text node
            ## treat the text as the first child node
            texts = text_children(el)
            
            assert ( all ( [t.getparent() == el for t in texts] ) )
            
            assert( len (texts ) <= 2 )
            if len( texts) > 0:
                if texts[0].is_text:
                    assert el.text == texts[0]
                    middle_contents.append(texts[0] );
    
            el = el[0]
            
    #[ text_from_lxml_object( mc ) for mc in middle_contents ]
    print etree.tostring(el)
    #print etree.tostring(middle_contents[-1] )
    print end_container.is_tail
    print end_container.is_text
    print "escape while"
    #print list ( el.itertext() )
    #print 'ca'
    #commonanncestor.text
    #type(el)
    type( end_container )
    assert end_container in text_children(el)
    
    assert el == end_container.getparent()
    
    print etree.tostring( end_container.getparent() )
    #print middle_contents[-2:] 
    #print end_container
    text_children(el )
    etree.tostring( el.getparent() )
    #p_el = el.getparent()
    #print etree.tostring( p_el )
    #text_children( p_el )[0].is_text
    
    #annotation
    #list(p_el)
    if end_container.is_tail:
        assert len(text_children(el )) == 2
        
        middle_contents.append( text_children( el )[ 0] )
    
    else:
        assert end_container.is_text
        
    end_text = end_container[:annotation['end_offset'] - 1]
    
    print 'start container'
    print etree.tostring( start_container.getparent())
    print start_container
    print 'offset', annotation['start_offset']
    
    print 'end container'
    print etree.tostring( end_container.getparent())
    print end_container
    print 'offset', annotation['end_offset']
    
    #assert start_container.is_text
    
    start_text = start_container[annotation['start_offset']:]
    
    target_text = [ start_text ]
    target_text.extend( [ text_from_lxml_object( mc ) for mc in middle_contents ] )
    target_text.append( end_text )
    
    return target_text

# %%
import io

annotation = {u'end_offset': 67, u'end_xpath': u'/html[1]/body[1]/div[3]/section[1]/div[2]/hgroup[1]/h1[1]/text()[1]', u'start_offset': 0, 
              u'start_xpath': u'/html[1]/body[1]/div[3]/section[1]/div[2]/hgroup[1]/h1[1]/text()[1]'}

annotation = {u'end_offset': 142, u'end_xpath': u'/html[1]/body[1]/div[3]/section[1]/div[2]/div[1]/div[1]/div[1]/p[10]/text()[2]',
              u'start_offset': 0, u'start_xpath': u'/html[1]/body[1]/div[3]/section[1]/div[2]/div[1]/div[1]/div[1]/p[1]/text()[1]'}
annotation = {u'end_offset': 1, u'end_xpath': u'/html[1]/body[1]/div[3]/section[1]/div[2]/hgroup[1]/h5[1]/text()[3]',
              u'start_offset': 0, u'start_xpath': u'/html[1]/body[1]/div[3]/section[1]/div[2]/hgroup[1]/h5[1]/time[1]/text()[1]'}


downloads_id = 582815971
annotation = {u'end_offset': 123, u'end_xpath': u'/html[1]/body[1]/div[2]/div[1]/div[1]/div[3]/div[2]/div[1]/div[1]/div[1]/div[1]/div[1]/article[1]/p[1]/text()[1]', u'start_offset': 0,
              u'start_xpath': u'/html[1]/body[1]/div[2]/div[1]/div[1]/div[3]/div[2]/div[1]/div[1]/div[1]/div[1]/div[1]/article[1]/h1[1]/text()[1]'}

download = get_download( downloads_id )
raw_content = u'' + download[ 'raw_content' ]

#with io.open( '/tmp/' + str(downloads_id) + '.html' , 'w', encoding='utf8' ) as f:
#    f.write( raw_content )

get_annotated_text( u''+ raw_content, annotation )    
htmlparser = etree.HTMLParser()
root = etree.fromstring( raw_content, htmlparser )
d = root.xpath( annotation['start_xpath'] )[0]

p = d.getparent()
p.
# Out:
# sc Use OS X 10.10 Yosemite to place, receive phone calls
# ec As part of Apple's Continuity efforts, you can now leverage your nearby iPhone to place, receive phone calls from your Mac.
# common
# end inner loop
# end loop
# <Element article at 0x7f9de070f0f0>
# [<Element article at 0x7f9de070f0f0>, <Element div at 0x7f9de070f9b0>, <Element div at 0x7f9de070fcd0>, <Element div at 0x7f9de070fd20>, <Element div at 0x7f9de070f8c0>, <Element div at 0x7f9de070faf0>, <Element div at 0x7f9de070fe60>, <Element div at 0x7f9de070fc80>, <Element div at 0x7f9de070fdc0>, <Element div at 0x7f9de070ff00>, <Element div at 0x7f9de070fd70>, <Element body at 0x7f9de070ff50>, <Element html at 0x7f9de070f820>]
# False
# commonacccestor <Element article at 0x7f9de070f0f0>
# ca's processed children
# start True
# outer loop: <Element p at 0x7f9de070fbe0>
# <p class="article-dek" itemprop="description">As part of Apple's Continuity efforts, you can now leverage your nearby iPhone to place, receive phone calls from your Mac.</p>
#
#
#
# end inner loop
# found end_contain parent, exiting loop: <Element p at 0x7f9de070fbe0>
# <p class="article-dek" itemprop="description">As part of Apple's Continuity efforts, you can now leverage your nearby iPhone to place, receive phone calls from your Mac.</p>
#
#
#
# <p class="article-dek" itemprop="description">As part of Apple's Continuity efforts, you can now leverage your nearby iPhone to place, receive phone calls from your Mac.</p>
#
#
#
# False
# True
# escape while
# <p class="article-dek" itemprop="description">As part of Apple's Continuity efforts, you can now leverage your nearby iPhone to place, receive phone calls from your Mac.</p>
#
#
#
# start container
# <h1 itemprop="headline">Use OS X 10.10 Yosemite to place, receive phone calls</h1>
#
# Use OS X 10.10 Yosemite to place, receive phone calls
# offset 0
# end container
# <p class="article-dek" itemprop="description">As part of Apple's Continuity efforts, you can now leverage your nearby iPhone to place, receive phone calls from your Mac.</p>
#
#
#
# As part of Apple's Continuity efforts, you can now leverage your nearby iPhone to place, receive phone calls from your Mac.
# offset 123
# 339

# %%
annotation = {u'end_offset': 61, 
             u'start_offset': 0,
             u'end_xpath':   u'/html[1]/body[1]/div[2]/div[4]/div[1]/div[3]/div[1]/h1[1]/text()[1]',
             u'start_xpath': u'/html[1]/body[1]/div[2]/div[4]/div[1]/div[3]/div[1]/h1[1]/text()[1]'}
annotation = {u'end_offset': 28, u'end_xpath': u'/html[1]/body[1]/div[2]/div[4]/div[1]/div[3]/div[1]/div[1]/p[1]/span[3]/text()[1]', u'start_offset': 0, u'start_xpath': u'/html[1]/body[1]/div[2]/div[4]/div[1]/div[3]/div[1]/div[1]/p[1]/span[1]/text()[1]'}

annotation = {u'end_offset': 26, u'end_xpath': u'/html[1]/body[1]/div[2]/div[4]/div[1]/div[3]/div[1]/span[1]/p[15]/text()[2]', u'start_offset': 1, u'start_xpath': u'/html[1]/body[1]/div[2]/div[4]/div[1]/div[3]/div[1]/span[1]/span[2]/p[1]/text()[1]'}
annotation = {u'end_offset': 272, u'end_xpath': u'/html[1]/body[1]/div[2]/div[4]/div[1]/div[3]/div[1]/span[1]/p[2]/text()[1]', u'start_offset': 0, u'start_xpath': u'/html[1]/body[1]/div[2]/div[4]/div[1]/div[3]/div[1]/span[1]/p[1]/text()[1]'}

print annotation

get_annotated_text( raw_content, annotation )
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-214-d2e2ed8d91bd> in <module>()
#      10 print annotation
#      11
# ---> 12 get_annotated_text( raw_content, annotation )
#
# <ipython-input-212-18ad7bfc06a3> in get_annotated_text(raw_content, annotation)
#       6     #print annotation[ 'start_xpath' ]
#       7
# ----> 8     start_container = root.xpath( annotation[ 'start_xpath' ] )[0]
#       9     end_container   = root.xpath( annotation[ 'end_xpath' ] )[0]
#      10
#
# IndexError: list index out of range
# {u'end_offset': 272, u'end_xpath': u'/html[1]/body[1]/div[2]/div[4]/div[1]/div[3]/div[1]/span[1]/p[2]/text()[1]', u'start_offset': 0, u'start_xpath': u'/html[1]/body[1]/div[2]/div[4]/div[1]/div[3]/div[1]/span[1]/p[1]/text()[1]'}

# %%
import sqlite3

db = sqlite3.connect('extractor_train_dbs/dev_2014-10-23T11_02_21-0400.db')
db.row_factory = sqlite3.Row

cursor = db.cursor()

cursor.execute( "SELECT * from dlannotations where downloads_id =  582817308" )

row = cursor.fetchone()
print row
d = dict([ (k, row[k]) for k in row.keys() ])
d.keys()
d['annotations_json']
annotations = json.loads( d['annotations_json']  )
annotations
raw_content == d['raw_content']
#get_annotated_text( d['raw_content'], annotations[1] )
# Out:
# <sqlite3.Row object at 0x7f9de2203cd0>
# True

# %%
#print 'end el'
#print el
#print etree.tostring( el )


#print start_anncestors
#print end_anncestors

commonanncestors = list([ s for s in start_anncestors if s in end_anncestors ] )
commonanncestor = commonanncestors[0]

commonanncestor

#print commonanncestor
#print 'full dump'

#print etree.tostring( commonanncestor )
#parent = start_container.getparent()

#parent.getnext()

#parent.getnext().index( parent )
#list(parent.itertext() )
#list(parent)
#.index( start_container )

#root.xpath( '/html[1]/body[1]/div[2]/div[4]/div[1]/div[3]/div[1]/h1[1]/text()[1]'   )
#root.xpath( '/html[1]/body[1]/div[2]/div[4]/div[1]/div[3]/div[1]/div[1]/p[1]/span[1]/text()[1]' )
#res = root.xpath( '/html[1]/body[1]/div[2]/div[4]/div[1]/div[3]/div[1]/div[1]/p[1]/span[3]/text()[1]' )
#res = root.xpath( '/html[1]/body[1]/div[2]/div[4]/div[1]/div[3]/div[1]/span[1]/span[2]/p[1]/text()[1]' )
#res = root.xpath( '/html[1]/body[1]/div[2]/div[4]/div[1]/div[3]/div[1]/span[1]/p[15]/text()[2]' )
#len ( res[0] )
#res
# Out:
# <Element span at 0x7f9dee05ec80>

# %%
import difflib
from IPython.display import HTML

from collections import Counter

def ratcliff_obershelp_compare( actual_lines, expected_lines ):
    
    words_expected = lines_to_comparable_text(expected_lines ).split()
    words_crf      = lines_to_comparable_text(actual_lines ).split()
    
    differ = difflib.Differ( )
    
    #print words_crf[:10]
    #print words_expected[:10]
    list( differ.compare( words_crf , words_expected ) )
    counts = Counter([ d[0] for d in differ.compare( words_expected, words_crf   ) ])
    
    tp = counts[' ']
    fp = counts['+']
    fn = counts['-']
    
    precision = tp/float(tp+fp)
    recall    = tp/float( tp + fn )
    
    if ( precision + recall ) > 0:
        f1 = 2*(precision*recall)/( precision + recall )
    else:
        f1 = 0
    
    ret = { 'precision': precision,
        'recall': recall,
        'f1': f1
    }
    
    return ret

#ratcliff_obershelp_compare( words_crf, words_expected )

# %%
#downloads_id
#story
#raw_content
#expected_lines
#preprocessed_lines

def create_extractor_training_object( downloads_id, expected_lines=None ):
    download = get_download( downloads_id )
    
    raw_content = download[u'raw_content']
    stories_id = download[u'stories_id']
     
    story = requests.get('https://api.mediacloud.org/api/v2/stories/single/'+str(stories_id)+'?key='+api_key)
    
    story = story.json()[0]
    
    story_lines = get_story_lines( raw_content )
    #print story_lines.content
    preprocessed_lines = story_lines.json()
    
    if not expected_lines:
        expected_lines = get_extractor_training_text( downloads_id, preprocessed_lines  )

    ret = { 'downloads_id': downloads_id,
           'raw_content': raw_content,
           'story': story,
           'preprocessed_lines': preprocessed_lines,
           'expected_lines': expected_lines
           }
    
    return ret

# %%
def compare_extractors_for_download( downloads_id ):
    
    eto = create_extractor_training_object( downloads_id )
    
    return comp_extractors( eto )

    download = get_download( downloads_id )
    
    raw_content = download[u'raw_content']
    stories_id = download[u'stories_id']
     
    story = requests.get('https://api.mediacloud.org/api/v2/stories/single/'+str(stories_id)+'?key='+api_key)
    
    story = story.json()[0]
    
    story_lines = get_story_lines( raw_content )
    #print story_lines.content
    preprocessed_lines = story_lines.json()
    
    expected_lines = get_extractor_training_text( downloads_id, preprocessed_lines  )
    
    
    
def comp_extractors( eto ):    
    downloads_id = eto['downloads_id']
    story = eto['story']
    raw_content = eto['raw_content']
    preprocessed_lines = eto['preprocessed_lines']
    expected_lines = eto['expected_lines']
        
    title = story[u'title']
    description = story[u'description']
    url = story[u'url']
    
    heur_extract = extract_story( preprocessed_lines, title, description, 'HeuristicExtractor')
    crf_extract = extract_story( preprocessed_lines, title, description, 'CrfExtractor')
    
    heur_lines = get_extracted_text( heur_extract )
    crf_lines  = get_extracted_text( crf_extract )
    
    python_readability_lines = extract_with_python_readability( raw_content )
    
    py_goose_lines = extract_with_python_goose( raw_content )
    
    global glob_expected_lines
    global glob_crf_lines
    glob_expected_lines = expected_lines
    glob_crf_lines      = crf_lines
    
    tree = html.fromstring( extract_with_boilerpipe( raw_content) )   
    spans = tree.xpath('//span[@class="x-boilerpipe-mark1"]')
    boiler_pipe_lines = [ s.text for s in spans ]

    #print "expected_lines:"
    #print lines_to_comparable_text(expected_lines)
    
    #print "boilerpipe lines"
    #print lines_to_comparable_text(boiler_pipe_lines)
    
    comp_results = {}
    comp_results['heur'] = ratcliff_obershelp_compare( heur_lines, expected_lines )
    comp_results['crf']  = ratcliff_obershelp_compare( crf_lines, expected_lines )
    comp_results['boiler_pipe'] = ratcliff_obershelp_compare( boiler_pipe_lines, expected_lines )
    comp_results['python_readibilty'] = ratcliff_obershelp_compare( python_readability_lines, expected_lines )
    comp_results['py_goose'] = ratcliff_obershelp_compare( py_goose_lines, expected_lines )
    
    comp_results['downloads_id'] = downloads_id
    
    #comp_results['expected']    = compare_accuracy( expected_lines, expected_lines )
    return comp_results

# %%
comps_expected = comps

# %%
downloads_id = 416655019
downloads_ids = [391881020,401370599,412896439,412952145,412977048,413024519,413657081,413835576,414040102,414257623,
                 414377428,414480464,414818749,414983458,415185946,415186582,415197547,415424551,415978069,416026460,
                 416026587,416047494,416047513,416210404,416263840,416306952,416426245,416655019,416730837,416802690,
                 417347290,417347524,417368539,417389613,417477837,417653177,418489742,418544762,418574641,418648698,
                 418661859,419404469,419440474,419483895,419873979,420430754,420599387,420666122,421520860,421834553,
                 422181106,422280595,422910963,423318170,424080271,424369085,424796346,424840366,425206279,426405203,
                 426560018,426632784,426709900,428449440,429607289,430363249,430995428,433457459,435624796,435659593,461175103,461175549,461176415,461176844,461177487,461178557,461178590,461179203,461179222,461179441,461179762,461179818,461179954,461179956,461180307,461181039,461181597,461186137,461186258,461186833,461187188,461187261,461187577,461188549,461189069,461190586,461193383]

print len( downloads_ids )

comps = []

extractor_training_objects = []
for downloads_id in downloads_ids[:10]:
    print 'downloads_id:', downloads_id
    extractor_training_objects.append( create_extractor_training_object( downloads_id ) )
# Out:
# 97
# downloads_id: 391881020
# [30, 31]
# downloads_id: 401370599
# [202, 205, 212, 213]
# downloads_id: 412896439
# [265, 266, 267, 279, 281, 283, 285, 287, 289, 291, 293, 303, 305, 307, 309, 311, 313, 315, 702]
# downloads_id: 412952145
# [415, 422, 436, 440, 444, 448, 449, 450, 451, 455, 459]
# downloads_id: 412977048
# [471, 474, 505, 507]
# downloads_id: 413024519
# [606, 607, 608, 692, 694, 695, 696, 697]
# downloads_id: 413657081
# [597, 608, 613, 616, 624, 627, 630, 640, 644, 647, 650, 653, 656, 659, 662, 665]
# downloads_id: 413835576
# [283, 284, 304, 305, 306]
# downloads_id: 414040102
# [3270, 3273, 3377, 3439, 3444, 3448, 3450, 3452, 3454, 3456, 3458, 3460, 3462, 3464, 3465, 3467]
# downloads_id: 414257623
# [566, 569, 579, 580, 581, 582, 583, 584, 585, 586, 587, 588]

# %%
for extractor_training_object in extractor_training_objects:
    res = comp_extractors( extractor_training_object )
    #print res
    comps.append( res )
    

print 'Comps_expteced', comps_expected
print 'comps', comps
comps == comps_expected
# Out:
# [31, 32, 87, 88, 89, 90]
# [29, 30, 31, 32]
# original article tmp file
#  /tmp/tmpT3k6Wu.html
# /tmp/tmpj61Ic0.html
# /tmp/tmpT3k6Wu.html
# /tmp/tmpT3k6Wu.html
# Now open file:///tmp/tmpj61Ic0.html in your web browser
# [212, 303, 318, 333, 348, 404, 419, 420, 435, 436, 454, 554]
# [205, 212, 213]
# original article tmp file
#  /tmp/tmpRVITj2.html
# /tmp/tmpF8TawR.html
# /tmp/tmpRVITj2.html
# /tmp/tmpRVITj2.html
# Now open file:///tmp/tmpF8TawR.html in your web browser
# [265, 279, 281, 283, 285, 287, 289, 291, 293, 305, 307, 311, 313, 315]
# [265, 702]
# original article tmp file
#  /tmp/tmpBR0rbB.html
# /tmp/tmpcILNrI.html
# /tmp/tmpBR0rbB.html
# /tmp/tmpBR0rbB.html
# Now open file:///tmp/tmpcILNrI.html in your web browser
# [422, 436, 440, 444, 448, 449, 450, 451, 455, 459, 466, 522, 546, 570, 618, 624, 642, 666, 690, 714, 738, 762, 768, 786, 792, 810, 834, 840, 864, 906, 930, 1223]
# [422, 436, 440, 444, 448, 449, 450, 451, 455, 459]
# original article tmp file
#  /tmp/tmpjEveoH.html
# /tmp/tmp3yYqRj.html
# /tmp/tmpjEveoH.html
# /tmp/tmpjEveoH.html
# Now open file:///tmp/tmp3yYqRj.html in your web browser
# [471, 505, 507]
# [471]
# original article tmp file
#  /tmp/tmpXuw9Gd.html
# /tmp/tmpV73xny.html
# /tmp/tmpXuw9Gd.html
# /tmp/tmpXuw9Gd.html
# Now open file:///tmp/tmpV73xny.html in your web browser
# Unexpected error on string '<' <class 'lxml.etree.ParserError'>
# Unexpected error on string '<' <class 'lxml.etree.ParserError'>
# [606, 607, 694, 695, 696, 697, 989, 990, 1045, 1074, 1131, 1176, 1179, 1194]
# [606]
# original article tmp file
#  /tmp/tmpRdDwtD.html
# /tmp/tmp6asj4c.html
# /tmp/tmpRdDwtD.html
# /tmp/tmpRdDwtD.html
# Now open file:///tmp/tmp6asj4c.html in your web browser
# Unexpected error on string '	' <class 'lxml.etree.ParserError'>
# Unexpected error on string '	' <class 'lxml.etree.ParserError'>
# Unexpected error on string '	' <class 'lxml.etree.ParserError'>
# Unexpected error on string '	' <class 'lxml.etree.ParserError'>
# Unexpected error on string '	' <class 'lxml.etree.ParserError'>
# Unexpected error on string '	' <class 'lxml.etree.ParserError'>
# Unexpected error on string '	' <class 'lxml.etree.ParserError'>
# Unexpected error on string '	' <class 'lxml.etree.ParserError'>
# Unexpected error on string '	' <class 'lxml.etree.ParserError'>
# Unexpected error on string '<' <class 'lxml.etree.ParserError'>
# Unexpected error on string '<' <class 'lxml.etree.ParserError'>
# [597, 609, 613, 616, 624, 627, 630, 644, 647, 650, 656, 662, 665, 710, 721, 842, 853, 864, 875, 886, 1279, 1284, 1410, 1414]
# [597, 613, 616]
# original article tmp file
#  /tmp/tmph1F29i.html
# /tmp/tmpFVenm2.html
# /tmp/tmph1F29i.html
# /tmp/tmph1F29i.html
# Now open file:///tmp/tmpFVenm2.html in your web browser
# [218, 284, 306, 337, 338, 339]
# [304, 305, 306]
# original article tmp file
#  /tmp/tmppOP0Dl.html
# /tmp/tmpXZvrEP.html
# /tmp/tmppOP0Dl.html
# /tmp/tmppOP0Dl.html
# Now open file:///tmp/tmpXZvrEP.html in your web browser
# [3270, 3273, 3377, 3411, 3424, 3444, 3448, 3452, 3454, 3456, 3458, 3465, 3467, 3631, 3768, 3774, 3780, 3786, 3792, 3798, 3804, 3810, 3816, 3822, 3828, 3834, 3840, 3852, 3864, 3870, 3876, 3882, 3888]
# [178, 3270, 3273, 3439, 3444, 3448, 3450, 3452, 3454, 3456, 3458, 3533]
# original article tmp file
#  /tmp/tmpeAE8uG.html
# /tmp/tmpxCwzOH.html
# /tmp/tmpeAE8uG.html
# /tmp/tmpeAE8uG.html
# Now open file:///tmp/tmpxCwzOH.html in your web browser
# [569, 580, 581, 582, 583, 584, 585, 586, 587, 588, 737, 985, 1360, 1390, 1420, 1450, 1484, 1514, 1544, 1574, 1608, 1638, 1668, 1698, 1732, 1762, 1792, 1822]
# [569, 579, 580, 581, 582, 583, 584, 585, 586, 587, 588, 674]
# original article tmp file
#  /tmp/tmpmq6m7p.html
# /tmp/tmpT2sOv5.html
# /tmp/tmpmq6m7p.html
# /tmp/tmpmq6m7p.html
# Now open file:///tmp/tmpT2sOv5.html in your web browser
# Comps_expteced [{'heur': {'recall': 0.9744897959183674, 'precision': 0.834061135371179, 'f1': 0.8988235294117648}, 'boiler_pipe': {'recall': 0.8520408163265306, 'precision': 0.6139705882352942, 'f1': 0.7136752136752136}, 'downloads_id': 391881020, 'crf': {'recall': 1.0, 'precision': 0.7340823970037453, 'f1': 0.8466522678185745}, 'python_readibilty': {'recall': 0.9387755102040817, 'precision': 0.9435897435897436, 'f1': 0.9411764705882353}}]
# comps [{'downloads_id': 391881020, 'python_readibilty': {'recall': 0.9387755102040817, 'precision': 0.9435897435897436, 'f1': 0.9411764705882353}, 'heur': {'recall': 0.9744897959183674, 'precision': 0.834061135371179, 'f1': 0.8988235294117648}, 'crf': {'recall': 1.0, 'precision': 0.7340823970037453, 'f1': 0.8466522678185745}, 'py_goose': {'recall': 0.9285714285714286, 'precision': 0.9238578680203046, 'f1': 0.926208651399491}, 'boiler_pipe': {'recall': 0.8520408163265306, 'precision': 0.6139705882352942, 'f1': 0.7136752136752136}}, {'downloads_id': 401370599, 'python_readibilty': {'recall': 1.0, 'precision': 0.9330143540669856, 'f1': 0.9653465346534654}, 'heur': {'recall': 0.8871794871794871, 'precision': 0.6975806451612904, 'f1': 0.7810383747178329}, 'crf': {'recall': 0.9692307692307692, 'precision': 1.0, 'f1': 0.9843749999999999}, 'py_goose': {'recall': 0.9435897435897436, 'precision': 1.0, 'f1': 0.9709762532981531}, 'boiler_pipe': {'recall': 0.9897435897435898, 'precision': 0.9796954314720813, 'f1': 0.9846938775510204}}, {'downloads_id': 412896439, 'python_readibilty': {'recall': 0.977859778597786, 'precision': 1.0, 'f1': 0.9888059701492538}, 'heur': {'recall': 0.9464944649446494, 'precision': 1.0, 'f1': 0.9725118483412322}, 'crf': {'recall': 0.02214022140221402, 'precision': 1.0, 'f1': 0.04332129963898917}, 'py_goose': {'recall': 0.5129151291512916, 'precision': 1.0, 'f1': 0.6780487804878049}, 'boiler_pipe': {'recall': 0.8376383763837638, 'precision': 0.631432545201669, 'f1': 0.7200634417129262}}, {'downloads_id': 412952145, 'python_readibilty': {'recall': 0.9828080229226361, 'precision': 0.9913294797687862, 'f1': 0.9870503597122302}, 'heur': {'recall': 0.9828080229226361, 'precision': 0.1819628647214854, 'f1': 0.30707251566696503}, 'crf': {'recall': 0.9828080229226361, 'precision': 1.0, 'f1': 0.9913294797687862}, 'py_goose': {'recall': 0.054441260744985676, 'precision': 1.0, 'f1': 0.10326086956521738}, 'boiler_pipe': {'recall': 0.09742120343839542, 'precision': 0.026813880126182965, 'f1': 0.042053184910327765}}, {'downloads_id': 412977048, 'python_readibilty': {'recall': 1.0, 'precision': 0.944, 'f1': 0.9711934156378601}, 'heur': {'recall': 0.9491525423728814, 'precision': 1.0, 'f1': 0.9739130434782608}, 'crf': {'recall': 0.03389830508474576, 'precision': 0.06060606060606061, 'f1': 0.04347826086956522}, 'py_goose': {'recall': 0.9491525423728814, 'precision': 1.0, 'f1': 0.9739130434782608}, 'boiler_pipe': {'recall': 0.9661016949152542, 'precision': 0.8976377952755905, 'f1': 0.9306122448979591}}, {'downloads_id': 413024519, 'python_readibilty': {'recall': 0.8805309734513275, 'precision': 0.995, 'f1': 0.9342723004694836}, 'heur': {'recall': 0.9203539823008849, 'precision': 0.6540880503144654, 'f1': 0.7647058823529412}, 'crf': {'recall': 0.03982300884955752, 'precision': 0.1323529411764706, 'f1': 0.061224489795918366}, 'py_goose': {'recall': 0.3407079646017699, 'precision': 1.0, 'f1': 0.5082508250825082}, 'boiler_pipe': {'recall': 0.37168141592920356, 'precision': 0.717948717948718, 'f1': 0.4897959183673469}}, {'downloads_id': 413657081, 'python_readibilty': {'recall': 1.0, 'precision': 0.8926014319809069, 'f1': 0.9432534678436317}, 'heur': {'recall': 0.8743315508021391, 'precision': 0.8650793650793651, 'f1': 0.8696808510638298}, 'crf': {'recall': 0.17914438502673796, 'precision': 1.0, 'f1': 0.3038548752834467}, 'py_goose': {'recall': 0.09090909090909091, 'precision': 1.0, 'f1': 0.16666666666666669}, 'boiler_pipe': {'recall': 0.8235294117647058, 'precision': 0.7439613526570048, 'f1': 0.7817258883248731}}, {'downloads_id': 413835576, 'python_readibilty': {'recall': 0.9708454810495627, 'precision': 1.0, 'f1': 0.985207100591716}, 'heur': {'recall': 0.9125364431486881, 'precision': 0.7262180974477959, 'f1': 0.8087855297157623}, 'crf': {'recall': 0.9358600583090378, 'precision': 1.0, 'f1': 0.966867469879518}, 'py_goose': {'recall': 0.8542274052478134, 'precision': 0.9015384615384615, 'f1': 0.8772455089820359}, 'boiler_pipe': {'reca ...
# False

# %%
download = get_download( 391881020 )
download['raw_content']
download['url']
#None
# Out:
# u'http://virgula.uol.com.br/inacreditavel/bizarro/metro-tem-confusao-por-causa-de-encontro-em-shopping'

# %%
print lines_to_comparable_text( extract_with_python_readability( download['raw_content' ] ) )
# Out:
# Metrô tem confusão por causa de encontro em shopping; veja vídeo Era para ser um sábado muvucado como todos aqueles que antecedem o Natal em mais um shopping de São Paulo. Mas foi muito mais do que isso. Milhares de jovens compareceram a um encontro promovido por uma página no Facebook para este sábado (7), no segundo andar do Shopping Metrô Itaquera, às 17h. Mas o que aconteceu foi uma bagunça total, com a chegada da polícia e o fechamento do shopping duas horas antes que o previsto.Ninguém sabe ao certo o que aconteceu, alguns dizem que foi arrastão, mas os próprios lojistas negam. De acordo com um rapaz que registrou a movimentação na saída do metrô, algumas pessoas isoladamente tiveram itens furtados. Infelizmente, o celular do garoto era meio ruim, mas deu para ver a confusão. Veja aqui o vídeo que ele fez.Como muita gente compareceu, houve a confusão. O certo é que já está marcado o terceiro encontro, que é mais uma badalação entre a galera, ou melhor, como diz a própria página, é só um Rolêzinho Parte 3. Tudo começou na semana passado, no domingo (1), com o Vuuk no Shopping Itaquera.

# %%
import readability

doc = readability.Document( download['raw_content'] )

doc.content()

print doc.short_title()
print lines_to_comparable_text( [ doc.summary() ] )
# Out:
# Metrô tem confusão por causa de encontro em shopping; veja vídeo
# Era para ser um sábado muvucado como todos aqueles que antecedem o Natal em mais um shopping de São Paulo. Mas foi muito mais do que isso. Milhares de jovens compareceram a um encontro promovido por uma página no Facebook para este sábado (7), no segundo andar do Shopping Metrô Itaquera, às 17h. Mas o que aconteceu foi uma bagunça total, com a chegada da polícia e o fechamento do shopping duas horas antes que o previsto.Ninguém sabe ao certo o que aconteceu, alguns dizem que foi arrastão, mas os próprios lojistas negam. De acordo com um rapaz que registrou a movimentação na saída do metrô, algumas pessoas isoladamente tiveram itens furtados. Infelizmente, o celular do garoto era meio ruim, mas deu para ver a confusão. Veja aqui o vídeo que ele fez.Como muita gente compareceu, houve a confusão. O certo é que já está marcado o terceiro encontro, que é mais uma badalação entre a galera, ou melhor, como diz a própria página, é só um Rolêzinho Parte 3. Tudo começou na semana passado, no domingo (1), com o Vuuk no Shopping Itaquera.
# /usr/local/lib/python2.7/dist-packages/readability/htmls.py:107: FutureWarning: The behavior of this method will change in future versions. Use specific 'len(elem)' or 'elem is not None' test instead.
#   raw_html = unicode(tostring(doc.body or doc))

# %%
import sqlite3

db = sqlite3.connect('extractor_train_dbs/dev_2014-10-23T11_02_21-0400.db')
db.row_factory = sqlite3.Row

cursor = db.cursor()

cursor.execute( "SELECT * from dlannotations  order by downloads_id" )

extractor_training_objects = []

skipped_downloads = 0
for row in list( cursor.fetchall() )[:5]:
    row =  dict([ (k, row[k]) for k in row.keys() ])
    
    #print row
    
    row['annotations'] = json.loads( row['annotations_json'] )
    row['raw_content'] = u'' + row['raw_content']
    annotated_text  = []
    
    try:
        annotations = row['annotations']
        for annotation in annotations:
            download = get_download( row['downloads_id'] )
    
            raw_content = u'' + download[u'raw_content']
            annotated_text.extend(get_annotated_text( u''+ raw_content, annotation ))
        
        eto = create_extractor_training_object( downloads_id, expected_lines=annotated_text )
        
        #assert eto['raw_content'] != row['raw_content']
        
        if eto['raw_content'] != row['raw_content']:
            #TODO figure out why these may differ
            pass
        
            #d = difflib.Differ()
            #diff = d.compare(eto['raw_content'].splitlines(1), row['raw_content'].splitlines(1))
            #print '\n'.join(diff)
        
        extractor_training_objects.append( eto )
        
    except:
        print "error"
        print 'downloads_id', row['downloads_id']
        print annotation
        skipped_downloads += 1
        #raise

print "skipped", skipped_downloads
print "processed", len(extractor_training_objects)
# Out:
#  California's unemployment rate dropped to 7.3% in September -- the lowest in more than six years -- though the total number of jobs declined by 9,800 last month, according to state data.
# ec <Element p at 0x7f9de05b6320>
# common
# end inner loop
# end loop
# <Element div at 0x7f9de05b64b0>
# [<Element div at 0x7f9de05b64b0>, <Element div at 0x7f9de05b6460>, <Element section at 0x7f9de05b6050>, <Element article at 0x7f9de05b60a0>, <Element div at 0x7f9de05b6190>, <Element div at 0x7f9de05b6550>, <Element div at 0x7f9de05b6140>, <Element body at 0x7f9de05b61e0>, <Element html at 0x7f9de05b62d0>]
# False
# commonacccestor <Element div at 0x7f9de05b64b0>
# ca's processed children
# start True
# outer loop: <Element p at 0x7f9de05b6320>
# <p>The small one-month dip in state jobs comes after months of steady employment growth in the state. Since September 2013, California has added nearly 300,000 new jobs.</p>
# end inner loop
# found end_contain parent, exiting loop: <Element p at 0x7f9de05b6320>
# <p>The small one-month dip in state jobs comes after months of steady employment growth in the state. Since September 2013, California has added nearly 300,000 new jobs.</p>
# error
# downloads_id 582818684
# {u'end_offset': 0, u'end_xpath': u'/html[1]/body[1]/div[2]/div[2]/div[1]/article[1]/section[1]/div[1]/div[1]/p[2]', u'start_offset': 1, u'start_xpath': u'/html[1]/body[1]/div[2]/div[2]/div[1]/article[1]/section[1]/div[1]/div[1]/p[1]/text()[1]'}
# sc
#  By
# ec David S. Cloud
# common
# end inner loop
# end loop
# <Element span at 0x7f9de05b6870>
# [<Element span at 0x7f9de05b6870>, <Element span at 0x7f9de05b68c0>, <Element div at 0x7f9ddbc8b0f0>, <Element div at 0x7f9de01215a0>, <Element header at 0x7f9de01218c0>, <Element article at 0x7f9de0121460>, <Element div at 0x7f9de0121140>, <Element div at 0x7f9de01210f0>, <Element div at 0x7f9de0121730>, <Element body at 0x7f9de01216e0>, <Element html at 0x7f9de00b96e0>]
# False
# commonacccestor <Element span at 0x7f9de05b6870>
# ca's processed children
# start True
# outer loop: <Element a at 0x7f9de05b6640>
# <a class="trb_bylines_name_author_a" href="/la-bio-david-cloud-staff.html">David S. Cloud</a>
# end inner loop
# found end_contain parent, exiting loop: <Element a at 0x7f9de05b6640>
# <a class="trb_bylines_name_author_a" href="/la-bio-david-cloud-staff.html">David S. Cloud</a>
# <a class="trb_bylines_name_author_a" href="/la-bio-david-cloud-staff.html">David S. Cloud</a>
# False
# True
# escape while
# <a class="trb_bylines_name_author_a" href="/la-bio-david-cloud-staff.html">David S. Cloud</a>
# start container
# <span class="trb_bylines_name_author_by">By </span>
# By
# offset 0
# end container
# <a class="trb_bylines_name_author_a" href="/la-bio-david-cloud-staff.html">David S. Cloud</a>
# David S. Cloud
# offset 14
# error
# downloads_id 582818686
# {u'end_offset': 147, u'end_xpath': u'/html[1]/body[1]/div[2]/div[3]/div[1]/article[1]/section[1]/div[1]/div[1]/p[1]/text()[2]', u'start_offset': 2, u'start_xpath': u'/html[1]/body[1]/div[2]/div[3]/div[1]/article[1]/section[1]/div[1]/div[1]/p[1]/text()[1]'}
# sc
#  London bus art displayed in Trafalgar Square
# ec  Last updated at 17:29 BST
# common
# end inner loop
# end loop
# <Element div at 0x7f9de05b6410>
# [<Element div at 0x7f9de05b6410>, <Element div at 0x7f9de05b6f50>, <Element div at 0x7f9de05b64b0>, <Element div at 0x7f9de05b6460>, <Element div at 0x7f9de05b6050>, <Element div at 0x7f9de05b60a0>, <Element div at 0x7f9de05b6190>, <Element div at 0x7f9de05b6550>, <Element div at 0x7f9de05b6140>, <Element div at 0x7f9de05b61e0>, <Element div at 0x7f9de05b62d0>, <Element div at 0x7f9de05b6320>, <Element div at 0x7f9de05b6dc0>, <Element div at 0x7f9de05b69b0>, <Element div at 0x7f9ddbc8b4b0>, <Element body at 0x7f9ddbc8b140>, <Element html at 0x7f9de05b6280>]
# False
# commonacccestor <Element div at 0x7f9de05b6410>
# ca's processed children
# start True
# outer loop: <Element p at 0x7f9ddbc8ba00>
# <p class="date date--v1" data-seconds="1413563384"><strong>17 October 2014</strong> Last updated at 17:29 BST </p>
# end inner loop
# outer loop: <Element strong at 0x7f9de05b6370>
# <strong>17 October 2014</strong> Last updated at 17:29 BST
# end inner loop
# found end_contain parent, exiting loop: <Element strong at 0x7f9de05b6370>
# <strong>17 October 2014</strong> Last updated at 17:29 BST
# <strong>17 October 2014</strong> Last updated at 17:29 BST
# True
# False
# escape while
# <strong>17 October 2014</strong> Last updated at 17:29 BST
# start container
# <h1 class="story-body__h1" data-asset-uri="/news/uk-england-london-29660835">London bus art displayed in Trafalgar Square</h1>
# London bus art displayed in Trafalgar Square
# offset 0
# end container
# <strong>17 October 2014</strong> Last updated at 17:29 BST
#  Last updated at 17:29 BST
# offset 26
# error
# downloads_id 582818944
# {u'end_offset': 23, u'end_xpath': u'/html[1]/body[1]/div[4]/div[1]/div[1]/div[1]/div[1]/div[2]/div[3]/div[1]/div[1]/div[1]/div[1]/div[1]/div[1]/div[3]/div[1]/div[2]/p[3]/text()[1]', u'start_offset': 0, u'start_xpath': u'/html[1]/body[1]/div[4]/div[1]/div[1]/div[1]/div[1]/div[2]/div[3]/div[1]/div[1]/div[1]/div[1]/div[1]/div[1]/div[3]/div[1]/div[2]/p[1]/text()[1]'}
# sc
#  As clock winds down, CP Rail's Harrison hunts for his dream deal
# ec Fri Oct 17, 2014 12:44pm EDT
# common
# end inner loop
# end loop
# <Element div at 0x7f9de05b6640>
# [<Element div at 0x7f9de05b6640>, <Element div at 0x7f9de05b6730>, <Element div at 0x7f9de05b6910>, <Element div at 0x7f9de05b60f0>, <Element div at 0x7f9de05b67d0>, <Element body at 0x7f9de05b6c30>, <Element html at 0x7f9de00b96e0>]
# False
# commonacccestor <Element div at 0x7f9de05b6640>
# ca's processed children
# start True
# outer loop: <Element div at 0x7f9de05b6d70>
# <div id="articleInfo">
#         <p class="byline">By Allison Martell and <a href="http://blogs.reuters.com/search/journalist.php?edition=us&amp;n=nick.carey&amp;">Nick Carey</a></p>
#         <p>
#         <span class="location">TORONTO/CHICAGO</span> <span class="pipe"> </span>
#         <span class="timestamp">Fri Oct 17, 2014 12:44pm EDT</span>
#         </p>
#     </div>
#
# end inner loop
# outer loop: <Element p at 0x7f9de05b6b40>
# <p class="byline">By Allison Martell and <a href="http://blogs.reuters.com/search/journalist.php?edition=us&amp;n=nick.carey&amp;">Nick Carey</a></p>
#
# inner loop
# end inner loop
# outer loop: <Element span at 0x7f9de05b65f0>
# <span class="location">TORONTO/CHICAGO</span>
# inner loop
# inner loop
# end inner loop
# found end_contain parent, exiting loop: <Element span at 0x7f9de05b6be0>
# <span class="timestamp">Fri Oct 17, 2014 12:44pm EDT</span>
#
# <span class="timestamp">Fri Oct 17, 2014 12:44pm EDT</span>
#
# False
# True
# escape while
# <span class="timestamp">Fri Oct 17, 2014 12:44pm EDT</span>
#
# start container
# <h1>As clock winds down, CP Rail's Harrison hunts for his dream deal</h1>
#
#
# As clock winds down, CP Rail's Harrison hunts for his dream deal
# offset 0
# end container
# <span class="timestamp">Fri Oct 17, 2014 12:44pm EDT</span>
#
# Fri Oct 17, 2014 12:44pm EDT
# offset 28
# sc
#   Oct 17 (Reuters) - Veteran railroad boss
# Hunter Harrison has won over many critics since taking over as
# chief executive of Canadian Pacific Railway, but he
# still has unfinished business - creation of a consolidated North
# American railway - and he is running out of time to do it.
# ec  in New York; Editing
# by Amran Abocar; and Peter Galloway)
# common
# end inner loop
# end inner loop
# end inner loop
# end loop
# <Element span at 0x7f9de05b6730>
# [<Element span at 0x7f9de05b6730>, <Element div at 0x7f9de05b6910>, <Element div at 0x7f9de05b60f0>, <Element div at 0x7f9de05b67d0>, <Element div at 0x7f9de05b6c30>, <Element div at 0x7f9de05b6be0>, <Element body at 0x7f9de05b6d70>, <Element html at 0x7f9de00b96e0>]
# False
# commonacccestor <Element span at 0x7f9de05b6730>
# ca's processed children
# start True
# outer loop: <Element span at 0x7f9de05b6f00>
# <span id="midArticle_1"></span>
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# end inner loop
# outer loop: <Element a at 0x7f9de05b6a00>
# <a href="http://blogs.reuters.com/search/journalist.php?edition=us&amp;n=paritosh.bansal&amp;">Paritosh Bansal</a> in New York; Editing
# by Amran Abocar; and Peter Galloway)
# end inner loop
# found end_contain parent, exiting loop: <Element a at 0x7f9de05b6a00>
# <a href="http://blogs.reuters.com/search/journalist.php?edition=us&amp;n=paritosh.bansal&amp;">Paritosh Bansal</a> in New York; Editing
# by Amran Abocar; and Peter Galloway)
# <a href="http://blogs.reuters.com/search/journalist.php?edition=us&amp;n=paritosh.bansal&amp;">Paritosh Bansal</a> in New York; Editing
# by Amran Abocar; and Peter Galloway)
# True
# False
# escape while
# <a href="http://blogs.reuters.com/search/journalist.php?edition=us&amp;n=paritosh.bansal&amp;">Paritosh Bansal</a> in New York; Editing
# by Amran Abocar; and Peter Galloway)
# start container
# <span class="articleLocation">TORONTO/CHICAGO</span> Oct 17 (Reuters) - Veteran railroad boss
# Hunter Harrison has won over many critics since taking over as
# chief executive of Canadian Pacific Railway, but he
# still has unfinished business - creation of a consolidated North
# American railway - and he is running out of time to do it.
#  Oct 17 (Reuters) - Veteran railroad boss
# Hunter Harrison has won over many critics since taking over as
# chief executive of Canadian Pacific Railway, but he
# still has unfinished business - creation of a consolidated North
# American railway - and he is running out of time to do it.
# offset 1
# end container
# <a href="http://blogs.reuters.com/search/journalist.php?edition=us&amp;n=paritosh.bansal&amp;">Paritosh Bansal</a> in New York; Editing
# by Amran Abocar; and Peter Galloway)
#  in New York; Editing
# by Amran Abocar; and Peter Galloway)
# offset 58
# sc
#   BY
# ec  Rachel Maresca
# common
# end loop
# <Element div at 0x7f9ddbc8bcd0>
# [<Element div at 0x7f9ddbc8bcd0>, <Element header at 0x7f9ddbc8baf0>, <Element main at 0x7f9ddbc8bd20>, <Element div at 0x7f9ddbc8b870>, <Element div at 0x7f9ddbc8b550>, <Element body at 0x7f9ddbc8b780>, <Element html at 0x7f9ddbc8b8c0>]
# False
# commonacccestor <Element div at 0x7f9ddbc8bcd0>
# ca's processed children
# error
# downloads_id 582819192
# {u'end_offset': 16, u'end_xpath': u'/html[1]/body[1]/div[1]/div[1]/main[1]/header[1]/div[1]/a[1]/text()[1]', u'start_offset': 1, u'start_xpath': u'/html[1]/body[1]/div[1]/div[1]/main[1]/header[1]/div[1]/text()[1]'}
# sc
#  A multi-million pound divorce between a wealthy Malaysian couple can be heard in an English court, a judge has ruled.
# ec The estranged pair married in 1970 and have five children together.
# common
# end inner loop
# end loop
# <Element div at 0x7f9ddbc8bfa0>
# [<Element div at 0x7f9ddbc8bfa0>, <Element div at 0x7f9ddbc8bb40>, <Element div at 0x7f9ddbc8b960>, <Element div at 0x7f9de0121870>, <Element div at 0x7f9de0121460>, <Element div at 0x7f9de0121d70>, <Element div at 0x7f9de0121910>, <Element div at 0x7f9de01216e0>, <Element div at 0x7f9de01215a0>, <Element body at 0x7f9de0121eb0>, <Element html at 0x7f9de05b6b40>]
# False
# commonacccestor <Element div at 0x7f9ddbc8bfa0>
# ca's processed children
# start True
# outer loop: <Element p at 0x7f9de0121b90>
# <p>Laura Ashley boss Khoo Kay Peng and former beauty queen Pauline Chai have already spent &#163;2m disputing which court should rule how the money is split.</p>&#13;
#
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# end inner loop
# found end_contain parent, exiting loop: <Element p at 0x7f9ddbc8b820>
# <p>The estranged pair married in 1970 and have five children together.</p>&#13;
#
#
#
# <p>The estranged pair married in 1970 and have five children together.</p>&#13;
#
#
#
# False
# True
# escape while
# <p>The estranged pair married in 1970 and have five children together.</p>&#13;
#
#
#
# start container
# <p class="introduction">A multi-million pound divorce between a wealthy Malaysian couple can be heard in an English court, a judge has ruled.</p>&#13;
#
# A multi-million pound divorce between a wealthy Malaysian couple can be heard in an English court, a judge has ruled.
# offset 0
# end container
# <p>The estranged pair married in 1970 and have five children together.</p>&#13;
#
#
#
# The estranged pair married in 1970 and have five children together.
# offset 67
# sc
#  17 October 2014
# ec <Element h3 at 0x7f9ddbc8bb40>
# common
# end inner loop
# end inner loop
# end loop
# <Element div at 0x7f9de05b6500>
# [<Element div at 0x7f9de05b6500>, <Element div at 0x7f9de05b6b40>, <Element div at 0x7f9de0121550>, <Element div at 0x7f9de0121870>, <Element div at 0x7f9de0121460>, <Element div at 0x7f9de0121d70>, <Element div at 0x7f9de0121910>, <Element div at 0x7f9de01216e0>, <Element div at 0x7f9de01215a0>, <Element body at 0x7f9de0121eb0>, <Element html at 0x7f9ddbc8b640>]
# False
# commonacccestor <Element div at 0x7f9de05b6500>
# ca's processed children
# start True
# outer loop: <Element div at 0x7f9de0121b90>
# <div id="page-bookmark-links-head" class="share-help">&#13;
#   <h3>Share this page</h3>&#13;
#   <ul>  	&#13;
#     <li class="delicious">&#13;
#       <a title="Post this story to Delicious" href="http://del.icio.us/post?url=http://www.bbc.co.uk/news/uk-29657028&amp;title=BBC+News+-+Multi-million+pound+divorce+%27can+be+heard+in+England%27">Delicious</a>&#13;
#     </li>&#13;
#     <li class="digg">&#13;
#       <a title="Post this story to Digg" href="http://digg.com/submit?url=http://www.bbc.co.uk/news/uk-29657028&amp;title=BBC+News+-+Multi-million+pound+divorce+%27can+be+heard+in+England%27">Digg</a>&#13;
#     </li>&#13;
#     <li class="facebook">&#13;
#       <a title="Post this story to Facebook" href="http://www.facebook.com/sharer.php?u=http://www.bbc.co.uk/news/uk-29657028&amp;t=BBC+News+-+Multi-million+pound+divorce+%27can+be+heard+in+England%27">Facebook</a>&#13;
#     </li>&#13;
#     <li class="reddit">&#13;
#       <a title="Post this story to reddit" href="http://reddit.com/submit?url=http://www.bbc.co.uk/news/uk-29657028&amp;title=BBC+News+-+Multi-million+pound+divorce+%27can+be+heard+in+England%27">reddit</a>&#13;
#     </li>&#13;
#     <li class="stumbleupon">&#13;
#       <a title="Post this story to StumbleUpon" href="http://www.stumbleupon.com/submit?url=http://www.bbc.co.uk/news/uk-29657028&amp;title=BBC+News+-+Multi-million+pound+divorce+%27can+be+heard+in+England%27">StumbleUpon</a>&#13;
#     </li>&#13;
#     <li class="twitter">&#13;
#       <a title="Post this story to Twitter" href="http://twitter.com/home?status=BBC+News+-+Multi-million+pound+divorce+%27can+be+heard+in+England%27+http://www.bbc.co.uk/news/uk-29657028">Twitter</a>&#13;
#     </li>&#13;
#     <li class="email">&#13;
#       <a title="Email this story" href="http://newsvote.bbc.co.uk/mpapps/pagetools/email/www.bbc.co.uk/news/uk-29657028">Email</a>&#13;
#     </li>&#13;
#     <li class="print">&#13;
#       <a title="Print this story" href="?print=true">Print</a>&#13;
#     </li>&#13;
#   </ul>&#13;
# <!--  Social media icons by Paul Annet | http://nicepaul.com/icons  -->&#13;
# </div>&#13;
#
# end inner loop
# outer loop: <Element h3 at 0x7f9ddbc8bb40>
# <h3>Share this page</h3>&#13;
#
# end inner loop
# found end_contain parent, exiting loop: <Element h3 at 0x7f9ddbc8bb40>
# <h3>Share this page</h3>&#13;
#
# error
# downloads_id 582819193
# {u'end_offset': 0, u'end_xpath': u'/html[1]/body[1]/div[4]/div[1]/div[1]/div[1]/div[1]/div[2]/div[3]/div[2]/div[1]/div[1]/h3[1]', u'start_offset': 0, u'start_xpath': u'/html[1]/body[1]/div[4]/div[1]/div[1]/div[1]/div[1]/div[2]/div[3]/div[2]/div[1]/span[1]/span[1]/text()[1]'}
# sc
#  Mullen: Marines will comply with 'don't ask, don't tell' repeal
# ec the CNN Wire Staff
# common
# end inner loop
# end loop
# <Element div at 0x7f9ddbc8beb0>
# [<Element div at 0x7f9ddbc8beb0>, <Element div at 0x7f9ddbc8ba50>, <Element div at 0x7f9ddbc8bf50>, <Element div at 0x7f9ddbc8be10>, <Element body at 0x7f9ddbc8b5f0>, <Element html at 0x7f9de05b6a00>]
# False
# commonacccestor <Element div at 0x7f9ddbc8beb0>
# ca's processed children
# start True
# outer loop: <!--startclickprintexclude-->
# <!--startclickprintexclude-->
# inner loop
# inner loop
# end inner loop
# outer loop: <Element div at 0x7f9ddbc8bbe0>
# <div class="cnnByline">By <b>the CNN Wire Staff</b><script type="text/javascript">cnnAuthor = "By the CNN Wire Staff";</script></div>
# end inner loop
# outer loop: <Element b at 0x7f9ddbc8b820>
# <b>the CNN Wire Staff</b>
# end inner loop
# found end_contain parent, exiting loop: <Element b at 0x7f9ddbc8b820>
# <b>the CNN Wire Staff</b>
# <b>the CNN Wire Staff</b>
# False
# True
# escape while
# <b>the CNN Wire Staff</b>
# start container
# <h1>Mullen: Marines will comply with 'don't ask, don't tell' repeal</h1>
# Mullen: Marines will comply with 'don't ask, don't tell' repeal
# offset 0
# end container
# <b>the CNN Wire Staff</b>
# the CNN Wire Staff
# offset 18
# error
# downloads_id 582819267
# {u'end_offset': 141, u'end_xpath': u'/html[1]/body[1]/div[2]/div[1]/div[1]/div[5]/div[8]/p[9]/text()[1]', u'start_offset': 0, u'start_xpath': u'/html[1]/body[1]/div[2]/div[1]/div[1]/div[5]/div[8]/p[1]/b[1]/text()[1]'}
# sc
#  By
# ec Published: September 27, 2009
# common
# end inner loop
# end inner loop
# end loop
# <Element div at 0x7f9ddbc8b960>
# [<Element div at 0x7f9ddbc8b960>, <Element div at 0x7f9ddbc8b640>, <Element div at 0x7f9ddbc8bb40>, <Element div at 0x7f9ddbc8bfa0>, <Element div at 0x7f9ddbc8beb0>, <Element body at 0x7f9ddbc8ba50>, <Element html at 0x7f9de05b6500>]
# False
# commonacccestor <Element div at 0x7f9ddbc8b960>
# ca's processed children
# start True
# outer loop: <Element div at 0x7f9de05b6960>
# <div class="timestamp">Published: September 27, 2009 </div>
#
# end inner loop
# found end_contain parent, exiting loop: <Element div at 0x7f9de05b6960>
# <div class="timestamp">Published: September 27, 2009 </div>
#
# <div class="timestamp">Published: September 27, 2009 </div>
#
# False
# True
# escape while
# <div class="timestamp">Published: September 27, 2009 </div>
#
# start container
# <div class="byline">By <a href="http://topics.nytimes.com/top/reference/timestopics/people/j/andrew_jacobs/index.html?inline=nyt-per" title="More Articles by Andrew Jacobs">ANDREW JACOBS</a></div>
#
# By
# offset 0
# end container
# <div class="timestamp">Published: September 27, 2009 </div>
#
# Published: September 27, 2009
# offset 29
# error
# downloads_id 582819299
# {u'end_offset': 102, u'end_xpath': u'/html[1]/body[1]/div[1]/div[2]/div[3]/div[1]/div[1]/div[4]/nyt_text[1]/p[8]/text()[1]', u'start_offset': 0, u'start_xpath': u'/html[1]/body[1]/div[1]/div[2]/div[3]/div[1]/div[1]/div[4]/nyt_text[1]/p[1]/text()[1]'}
# sc
#
# One day after "The View" executive producer Barbara Walters billed and cooed over departing co-host Star Jones Reynolds, she opened the show by sticking a shiv in Star's gullet.
#
# ec
# "Then there were three," B-Wa said at the top of the show, in re the fact that the tacky kitchen table around which the gals cheep, cheep, cheep at the start of each show was noticeably Star-less, sporting merely the aforementioned B-Wa, Joy Behar and Elisabeth Hasselbeck.
#
# common
# end inner loop
# end loop
# <Element div at 0x7f9ddbc8b0a0>
# [<Element div at 0x7f9ddbc8b0a0>, <Element div at 0x7f9ddbc8b690>, <Element div at 0x7f9ddbc8b960>, <Element div at 0x7f9ddbc8b640>, <Element div at 0x7f9ddbc8bb40>, <Element div at 0x7f9ddbc8bfa0>, <Element body at 0x7f9ddbc8beb0>, <Element html at 0x7f9de05b6b40>]
# False
# commonacccestor <Element div at 0x7f9ddbc8b0a0>
# ca's processed children
# start True
# outer loop: <Element div at 0x7f9ddbc8ba50>
# <div id="body_after_content_column">
# <p>
# While this is way better TV than that treacly send-off Babs gave her other departing co-host, Meredith Vieira, earlier this month, it's unclear how this advances Babs's carefully constructed image as the Mother Abbess of TV journalism.
# </p>
# <p>
# "Then there were three," B-Wa said at the top of the show, in re the fact that the tacky kitchen table around which the gals cheep, cheep, cheep at the start of each show was noticeably Star-less, sporting merely the aforementioned B-Wa, Joy Behar and Elisabeth Hasselbeck.
# </p>
# <p>
# "This is truthfully a very difficult day for us and it is a sad day for us," B-Wa continued, her Sad Face now firmly screwed in place.
# </p>
# <p>
# Difficult and sad because the day before, Star had upstaged what we're certain would have been a riveting Babs-led discussion on air conditioning to announce she was leaving the show on which she had vamped for nine years.
# </p>
# <p>
# Upstaging B-Wa is a serious crime, and here's how she executed Star yesterday morning:
# </p>
# <p>
# "The truth is that Star has known for months that ABC did not want to renew her contract and that she would not be asked back in the fall," she told her studio audience in marked contrast to what she'd said 24 hours earlier about how important Star had been to the launch of the ABC daytime series.
# </p>
# <p>
# (That's because, B-Wa had told the New York Times the day before, ABC's research showed that Star's "negatives were rising" and "the audience was losing trust in her. They didn't believe some of the things she said.")
# </p>
# <p>
# Speaking of rising negatives and not believing some of the things a woman has said, B-Wa had been telling her fellow journalists for months that there was no truth to the rumor Star was being dropped from the show. In early May, while in Washington for a "coming out" dinner for Saudi Arabia's new ambassador, The Post's Reliable Source column said she told them that Star Jones was not being dropped from "The View." A couple of weeks earlier the New York Times quoted her as saying, "If Star wants to continue to be [on 'The View'], she is welcome."
# </p>
# <p>
# These days, B-Wa explains she told those little white misinformations to "protect Star."
# </p>
# <p>
# Back to yesterday's execution, where B-Wa was explaining to her studio audience that they have grown to dislike and mistrust Star, according to ABC research.
# </p>
# <p>
# "But we were never going to say this. We wanted to protect Star," B-Wa said.
# </p>
# </div>
#
# end inner loop
# outer loop: <Element p at 0x7f9ddbc8bd20>
# <p>
# While this is way better TV than that treacly send-off Babs gave her other departing co-host, Meredith Vieira, earlier this month, it's unclear how this advances Babs's carefully constructed image as the Mother Abbess of TV journalism.
# </p>
#
# inner loop
# end inner loop
# found end_contain parent, exiting loop: <Element p at 0x7f9de05b6960>
# <p>
# "Then there were three," B-Wa said at the top of the show, in re the fact that the tacky kitchen table around which the gals cheep, cheep, cheep at the start of each show was noticeably Star-less, sporting merely the aforementioned B-Wa, Joy Behar and Elisabeth Hasselbeck.
# </p>
#
# <p>
# "Then there were three," B-Wa said at the top of the show, in re the fact that the tacky kitchen table around which the gals cheep, cheep, cheep at the start of each show was noticeably Star-less, sporting merely the aforementioned B-Wa, Joy Behar and Elisabeth Hasselbeck.
# </p>
#
# False
# True
# escape while
# <p>
# "Then there were three," B-Wa said at the top of the show, in re the fact that the tacky kitchen table around which the gals cheep, cheep, cheep at the start of each show was noticeably Star-less, sporting merely the aforementioned B-Wa, Joy Behar and Elisabeth Hasselbeck.
# </p>
#
# start container
# <p>
# One day after "The View" executive producer Barbara Walters billed and cooed over departing co-host Star Jones Reynolds, she opened the show by sticking a shiv in Star's gullet.
# </p>
#
#
# One day after "The View" executive producer Barbara Walters billed and cooed over departing co-host Star Jones Reynolds, she opened the show by sticking a shiv in Star's gullet.
#
# offset 1
# end container
# <p>
# "Then there were three," B-Wa said at the top of the show, in re the fact that the tacky kitchen table around which the gals cheep, cheep, cheep at the start of each show was noticeably Star-less, sporting merely the aforementioned B-Wa, Joy Behar and Elisabeth Hasselbeck.
# </p>
#
#
# "Then there were three," B-Wa said at the top of the show, in re the fact that the tacky kitchen table around which the gals cheep, cheep, cheep at the start of each show was noticeably Star-less, sporting merely the aforementioned B-Wa, Joy Behar and Elisabeth Hasselbeck.
#
# offset 22
# error
# downloads_id 582819331
# {u'end_offset': 77, u'end_xpath': u'/html[1]/body[1]/div[2]/div[2]/div[1]/div[1]/div[2]/div[2]/div[2]/p[10]/text()[1]', u'start_offset': 1, u'start_xpath': u'/html[1]/body[1]/div[2]/div[2]/div[1]/div[1]/div[2]/div[2]/div[2]/p[1]/div[1]/text()[1]'}
# sc
#  Tornado season is just not what it used to be, study says
# ec <Element h6 at 0x7f9de01582d0>
# common
# end inner loop
# end inner loop
# end loop
# <Element article at 0x7f9de01586e0>
# [<Element article at 0x7f9de01586e0>, <Element div at 0x7f9de0158eb0>, <Element div at 0x7f9de0158c30>, <Element div at 0x7f9de0158500>, <Element div at 0x7f9de0158550>, <Element body at 0x7f9de0158370>, <Element html at 0x7f9de01584b0>]
# False
# commonacccestor <Element article at 0x7f9de01586e0>
# ca's processed children
# start True
# outer loop: <Element div at 0x7f9de01580f0>
# <div class="entry-meta">
# 		<div class="light-grey no-underline padB10">
#   <ul class="cf no-bullet">
#     <li class="left marR5">
#       <h6 class="byline uppercase franklin-bold">
#         By <a href="http://www.washingtonpost.com/people/angela-fritz" title="Visit Angela Fritz&#8217;s website" rel="external">Angela Fritz</a>      </h6>
#     </li>
#             <li class="left marR5">
#           <a class="blue" id="56213" href="mailto:Angela.Fritz@washpost.com?subject=Reader feedback for 'Tornado season is just not what it used to be, study says'" data-href="fritza56213washpost.com?subject=Reader feedback for 'Tornado season is just not what it used to be, study says'"><i class="icon-envelope"/></a>
#         </li>
#                     <li class="left"><h6 class="franklin-thin grey"><time datetime="2014-10-16T15:09:49+00:00">October 16 at 3:09 pm</time></h6></li>
#       </ul>
# </div>
#
# 		<div id="menu-share" class="borB1S borT1S cf hide-for-large marB10">
# 	<ul class="no-bullet left">
# 		<li class="left borR1S">
# 			<a class="block line-height-50 light-grey padLR20" data-social-name="facebook" href="#" onclick="window.open('https://www.facebook.com/sharer/sharer.php?u=http%3A%2F%2Fwww.washingtonpost.com%2Fblogs%2Fcapital-weather-gang%2Fwp%2F2014%2F10%2F16%2Ftornado-season-is-just-not-what-it-used-to-be-study-says%2F', 'facebook-share-dialog', 'width=626,height=436'); return false;"><i class="icon-facebook icon-large"/></a>
# 		</li>
# 		<li class="left borR1S">
# 			<a class="block line-height-50 light-grey padLR20" data-social-name="twitter" href="javascript:void(0)" onclick="window.open('http://www.twitter.com/intent/tweet?text=Tornado+season+is+just+not+what+it+used+to+be%2C+study+says&amp;url=http://wapo.st/11w674c','','width=550, height=350, scrollbars=no')"><i class="icon-twitter icon-large"/></a>
# 		</li>
# 		<li class="left borR1S">
# 			<a class="block line-height-50 light-grey padLR20 email-share" data-social-name="email" href="http://www.washingtonpost.com/blogs/capital-weather-gang/wp/2014/10/16/tornado-season-is-just-not-what-it-used-to-be-study-says//email/"><i class="icon-envelope icon-large"/></a>
# 		</li>
# 		<li class="left borR1S">
# 			<a class="block line-height-50 light-grey padLR20 print-share" data-social-name="print" href="http://www.washingtonpost.com/blogs/capital-weather-gang/wp/2014/10/16/tornado-season-is-just-not-what-it-used-to-be-study-says//?print=1"><i class="icon-print icon-large"/></a>
# 		</li>
# 		<li class="left borR1S hide-for-small has-dropdown">
# 			<a class="block line-height-50 light-grey padLR20" id="dropdown" href="javascript:void(0);"><strong>More </strong><i class="icon-caret-down"/></a>
# 			<ul class="dropdown no-bullet none">
# 				<li><a class="block light-grey padBT10 width-100" href="javascript:void(0)" data-social-name="linkedin" onclick="window.open('http://www.linkedin.com/shareArticle?mini=true&amp;url=http://www.washingtonpost.com/blogs/capital-weather-gang/wp/2014/10/16/tornado-season-is-just-not-what-it-used-to-be-study-says/&amp;title=Tornado+season+is+just+not+what+it+used+to+be%2C+study+says&amp;summary=Tornado+season+is+changing%2C+but+maybe+not+in+the+way+you+would+suspect.%C2%A0While%C2%A0the+number+of+tornado+days%C2%A0has+been+decreasing%2C+the+number+of+tornadoes+on+those+days+has+actually+been+increasing.+In+other+words%2C+big+tornado+days+are+on+the+rise.+The+study+looked+specifically+at+tornadoes+that+were+at+least+EF1+%28or+F1+before%C2%A02007%29+in+%5B%E2%80%A6%5D','','width=830,height=460,scrollbars=no');return false;"><center><i class="icon-linkedin icon-large"/></center></a></li>
# 				<li><a class="block light-grey padBT10 width-100" href="#" data-social-name="googleplus" onclick="window.open('https://plus.google.com/share?url=http%3A%2F%2Fwww.washingtonpost.com%2Fblogs%2Fcapital-weather-gang%2Fwp%2F2014%2F10%2F16%2Ftornado-season-is-just-not-what-it-used-to-be-study-says%2F','','width=832,height=472,scrollbars=no');return false;"><center><i class="icon-google-plus icon-large"/></center></a></li>
# 				<li><a class="block light-grey padBT10 width-100" data-social-name="tumblr" href="#" onclick="window.open('http://www.tumblr.com/share/link?url=http%3A%2F%2Fwww.washingtonpost.com%2Fblogs%2Fcapital-weather-gang%2Fwp%2F2014%2F10%2F16%2Ftornado-season-is-just-not-what-it-used-to-be-study-says%2F&amp;name=Tornado season is just not what it used to be, study says&amp;description=Tornado+season+is+changing%2C+but+maybe+not+in+the+way+you+would+suspect.%C2%A0While%C2%A0the+number+of+tornado+days%C2%A0has+been+decreasing%2C+the+number+of+tornadoes+on+those+days+has+actually+been+increasing.+In+other+words%2C+big+tornado+days+are+on+the+rise.+The+study+looked+specifically+at+tornadoes+that+were+at+least+EF1+%28or+F1+before%C2%A02007%29+in+%5B%26hellip%3B%5D','','width=550,height=450,scrollbars=no');return false;"><center><i class="icon-tumblr icon-large"/></center></a></li>
# 								<li><a class="block light-grey padBT10 width-100" data-social-name="pinterest" href="#" onclick="window.open('http://www.pinterest.com/pin/create/button/?url=http://www.washingtonpost.com/blogs/capital-weather-gang/wp/2014/10/16/tornado-season-is-just-not-what-it-used-to-be-study-says/&amp;media=http://img.washingtonpost.com/rf/image_908w/WashingtonPost/Content/Blogs/morning-mix/Images/Severe_Weather-0f97e.jpg&amp;description=Tornado season is just not what it used to be, study says',&#10;  '', 'menubar=no,toolbar=no,resizable=yes,scrollbars=yes,height=600,width=800');return false;" data-pin-do="buttonPin" data-pin-config="above"><center><i class="icon-pinterest icon-large"/></center></a></li>
#
# 			</ul>
# 		</li>
# 	</ul>
# 			<a class="block hide-for-small right line-height-50 light-grey padL5 padLR20 comments-share" href="http://www.washingtonpost.com/blogs/capital-weather-gang/wp/2014/10/16/tornado-season-is-just-not-what-it-used-to-be-study-says/#comments">
# 			<i class="icon-comment icon-large"/>
# 			<div class="inline comment-number echo-counter" guid="http://www.washingtonpost.com/blogs/capital-weather-gang/wp/2014/10/16/tornado-season-is-just-not-what-it-used-to-be-study-says/"><strong/></div>
# 			<strong>Comments</strong>
# 		</a>
#
# </div>
# 	</div>
#
# end inner loop
# outer loop: <Element div at 0x7f9de0158fa0>
# <div class="light-grey no-underline padB10">
#   <ul class="cf no-bullet">
#     <li class="left marR5">
#       <h6 class="byline uppercase franklin-bold">
#         By <a href="http://www.washingtonpost.com/people/angela-fritz" title="Visit Angela Fritz&#8217;s website" rel="external">Angela Fritz</a>      </h6>
#     </li>
#             <li class="left marR5">
#           <a class="blue" id="56213" href="mailto:Angela.Fritz@washpost.com?subject=Reader feedback for 'Tornado season is just not what it used to be, study says'" data-href="fritza56213washpost.com?subject=Reader feedback for 'Tornado season is just not what it used to be, study says'"><i class="icon-envelope"/></a>
#         </li>
#                     <li class="left"><h6 class="franklin-thin grey"><time datetime="2014-10-16T15:09:49+00:00">October 16 at 3:09 pm</time></h6></li>
#       </ul>
# </div>
#
#
# end inner loop
# outer loop: <Element ul at 0x7f9de0158640>
# <ul class="cf no-bullet">
#     <li class="left marR5">
#       <h6 class="byline uppercase franklin-bold">
#         By <a href="http://www.washingtonpost.com/people/angela-fritz" title="Visit Angela Fritz&#8217;s website" rel="external">Angela Fritz</a>      </h6>
#     </li>
#             <li class="left marR5">
#           <a class="blue" id="56213" href="mailto:Angela.Fritz@washpost.com?subject=Reader feedback for 'Tornado season is just not what it used to be, study says'" data-href="fritza56213washpost.com?subject=Reader feedback for 'Tornado season is just not what it used to be, study says'"><i class="icon-envelope"/></a>
#         </li>
#                     <li class="left"><h6 class="franklin-thin grey"><time datetime="2014-10-16T15:09:49+00:00">October 16 at 3:09 pm</time></h6></li>
#       </ul>
#
# end inner loop
# outer loop: <Element li at 0x7f9de01585a0>
# <li class="left marR5">
#       <h6 class="byline uppercase franklin-bold">
#         By <a href="http://www.washingtonpost.com/people/angela-fritz" title="Visit Angela Fritz&#8217;s website" rel="external">Angela Fritz</a>      </h6>
#     </li>
#
# end inner loop
# outer loop: <Element h6 at 0x7f9de01582d0>
# <h6 class="byline uppercase franklin-bold">
#         By <a href="http://www.washingtonpost.com/people/angela-fritz" title="Visit Angela Fritz&#8217;s website" rel="external">Angela Fritz</a>      </h6>
#
# end inner loop
# outer loop: <Element a at 0x7f9de01581e0>
# <a href="http://www.washingtonpost.com/people/angela-fritz" title="Visit Angela Fritz&#x2019;s website" rel="external">Angela Fritz</a>
# inner loop
# inner loop
# error
# downloads_id 582819369
# {u'end_offset': 0, u'end_xpath': u'/html[1]/body[1]/div[1]/div[5]/div[2]/div[1]/article[1]/div[1]/div[1]/ul[1]/li[1]/h6[1]', u'start_offset': 0, u'start_xpath': u'/html[1]/body[1]/div[1]/div[5]/div[2]/div[1]/article[1]/header[1]/h1[1]/text()[1]'}
# sc
#  As Gov. Cuomo visits the Caribbean, rival Rob Astorino gets down in the Bronx
# ec Friday, October 17, 2014, 1:34 PM
# common
# end inner loop
# end loop
# <Element header at 0x7f9de0158f50>
# [<Element header at 0x7f9de0158f50>, <Element main at 0x7f9de0158280>, <Element div at 0x7f9de01588c0>, <Element div at 0x7f9de0158820>, <Element body at 0x7f9de0158410>, <Element html at 0x7f9de0158140>]
# False
# commonacccestor <Element header at 0x7f9de0158f50>
# ca's processed children
# start True
# outer loop: <Element div at 0x7f9de0158e60>
# <div id="a-byline"> BY  <a rel="author" href="/authors?author=Ken Lovett" itemscope="" itemtype="http://schema.org/Person">Ken Lovett</a>    </div>
# inner loop
# inner loop
# end inner loop
# found end_contain parent, exiting loop: <Element div at 0x7f9de01587d0>
# <div id="a-date-published" content="2014-10-17T13:34:33">Friday, October 17, 2014, 1:34 PM</div>
# <div id="a-date-published" content="2014-10-17T13:34:33">Friday, October 17, 2014, 1:34 PM</div>
# False
# True
# escape while
# <div id="a-date-published" content="2014-10-17T13:34:33">Friday, October 17, 2014, 1:34 PM</div>
# start container
# <h1 id="a-header" itemprop="headline">As Gov. Cuomo visits the Caribbean, rival Rob Astorino gets down in the Bronx</h1>
# As Gov. Cuomo visits the Caribbean, rival Rob Astorino gets down in the Bronx
# offset 0
# end container
# <div id="a-date-published" content="2014-10-17T13:34:33">Friday, October 17, 2014, 1:34 PM</div>
# Friday, October 17, 2014, 1:34 PM
# offset 33
# sc
#
# 	While Gov. Cuomo is spending Friday in the Dominican Republican and Puerto Rico, his Republican challenger, Rob Astorino, is campaigning in Latino neighborhoods in the south Bronx — including cutting the rug with Puerto Rican seniors.
# ec
# 	“He’d rather be hanging out at the presidential palace in the Dominican Republic than hanging out like I am with Dominicans in New York,” he said.
# common
# end inner loop
# end loop
# <Element article at 0x7f9de0158410>
# [<Element article at 0x7f9de0158410>, <Element div at 0x7f9de0158140>, <Element main at 0x7f9de01587d0>, <Element div at 0x7f9de0158e60>, <Element div at 0x7f9de0158690>, <Element body at 0x7f9de0158870>, <Element html at 0x7f9de0158280>]
# False
# commonacccestor <Element article at 0x7f9de0158410>
# ca's processed children
# start True
# outer loop: <Element p at 0x7f9de0158730>
# <p>&#13;
# 	Astorino was touring with Sen. Ruben Diaz Sr., <a href="http://nydn.us/1s0B74Q">a Bronx Democrat who has endorsed him over Cuomo</a>.</p>&#13;
#
# inner loop
# inner loop
# inner loop
# inner loop
# end inner loop
# found end_contain parent, exiting loop: <Element p at 0x7f9de0158820>
# <p>&#13;
# 	&#8220;He&#8217;d rather be hanging out at the presidential palace in the Dominican Republic than hanging out like I am with Dominicans in New York,&#8221; he said.</p>&#13;
#
# <p>&#13;
# 	&#8220;He&#8217;d rather be hanging out at the presidential palace in the Dominican Republic than hanging out like I am with Dominicans in New York,&#8221; he said.</p>&#13;
#
# False
# True
# escape while
# <p>&#13;
# 	&#8220;He&#8217;d rather be hanging out at the presidential palace in the Dominican Republic than hanging out like I am with Dominicans in New York,&#8221; he said.</p>&#13;
#
# start container
# <p>&#13;
# 	While Gov. Cuomo is spending Friday in the Dominican Republican and Puerto Rico, his Republican challenger, Rob Astorino, is campaigning in Latino neighborhoods in the south Bronx &#8212; including cutting the rug with Puerto Rican seniors.</p>&#13;
#
#
# 	While Gov. Cuomo is spending Friday in the Dominican Republican and Puerto Rico, his Republican challenger, Rob Astorino, is campaigning in Latino neighborhoods in the south Bronx — including cutting the rug with Puerto Rican seniors.
# offset 2
# end container
# <p>&#13;
# 	&#8220;He&#8217;d rather be hanging out at the presidential palace in the Dominican Republic than hanging out like I am with Dominicans in New York,&#8221; he said.</p>&#13;
#
#
# 	“He’d rather be hanging out at the presidential palace in the Dominican Republic than hanging out like I am with Dominicans in New York,” he said.
# offset 148
# error
# downloads_id 582823477
# {u'end_offset': 24, u'end_xpath': u'/html[1]/body[1]/div[2]/div[2]/div[1]/div[1]/div[2]/div[1]/h1[1]/text()[2]', u'start_offset': 0, u'start_xpath': u'/html[1]/body[1]/div[2]/div[2]/div[1]/div[1]/div[2]/div[1]/h1[1]/text()[1]'}
# sc
#  New mother Mila Kunis takes the wheel in FIRST sighting since she and fiancé Ashton Kutcher welcomed daughter Wyatt
# ec
#   12:23 EST, 17 October 2014
#
# common
# end inner loop
# end loop
# <Element div at 0x7f9de01586e0>
# [<Element div at 0x7f9de01586e0>, <Element div at 0x7f9de0158eb0>, <Element div at 0x7f9de0158c30>, <Element div at 0x7f9de0158500>, <Element div at 0x7f9de0158550>, <Element div at 0x7f9de0158370>, <Element body at 0x7f9de01584b0>, <Element html at 0x7f9de0158f50>]
# False
# commonacccestor <Element div at 0x7f9de01586e0>
# ca's processed children
# start True
# outer loop: <Element p at 0x7f9de0158640>
# <p class="author-section byline-plain">By
#
# <a href="/home/search.html?s=&amp;authornamef=Cassie+Carpenter+for+MailOnline" class="author" rel="nofollow">Cassie Carpenter for MailOnline</a>
#
#
# </p>
#
# inner loop
# end inner loop
# outer loop: <Element span at 0x7f9de01581e0>
# <span class="article-timestamp article-timestamp-published">
#   <span class="article-timestamp-label">Published:</span>
#   12:23 EST, 17 October 2014
# </span>
#  |
# inner loop
# end inner loop
# outer loop: <Element span at 0x7f9de0158190>
# <span class="article-timestamp-label">Updated:</span>
#   12:23 EST, 17 October 2014
#
# end inner loop
# found end_contain parent, exiting loop: <Element span at 0x7f9de0158190>
# <span class="article-timestamp-label">Updated:</span>
#   12:23 EST, 17 October 2014
#
# <span class="article-timestamp-label">Updated:</span>
#   12:23 EST, 17 October 2014
#
# True
# False
# escape while
# <span class="article-timestamp-label">Updated:</span>
#   12:23 EST, 17 October 2014
# start container
# <h1>New mother Mila Kunis takes the wheel in FIRST sighting since she and fianc&#233; Ashton Kutcher welcomed daughter Wyatt</h1>
#
# New mother Mila Kunis takes the wheel in FIRST sighting since she and fiancé Ashton Kutcher welcomed daughter Wyatt
# offset 0
# end container
# <span class="article-timestamp-label">Updated:</span>
#   12:23 EST, 17 October 2014
#
#
#   12:23 EST, 17 October 2014
#
# offset 29
# sc
#  New mother Mila Kunis was spotted for the first time since welcoming daughter Wyatt Isabelle in Los Angeles Friday.
# ec The Golden Globe nominee and fiancé Ashton Kutcher were seen purchasing the family-friendly Lexus sedan late last month.
# common
# end inner loop
# end inner loop
# end loop
# <Element div at 0x7f9ddbf900a0>
# [<Element div at 0x7f9ddbf900a0>, <Element div at 0x7f9ddbf904b0>, <Element div at 0x7f9ddbf90190>, <Element div at 0x7f9ddbf90500>, <Element div at 0x7f9ddbf90460>, <Element div at 0x7f9ddbf90730>, <Element body at 0x7f9ddbf90690>, <Element html at 0x7f9ddbf90140>]
# False
# commonacccestor <Element div at 0x7f9ddbf900a0>
# ca's processed children
# start True
# outer loop: <Element p at 0x7f9dec0b35a0>
# <p class="mol-para-with-font"><font style="font-size:1.2em">Seated behind the wheel, the 31-year-old actress appeared tired as she drove her precious newborn, who was reportedly in a car seat in the back.</font></p>
# inner loop
# end inner loop
# outer loop: <Element font at 0x7f9ddbf90050>
# <font style="font-size:1.2em">The Golden Globe nominee and fianc&#233; Ashton Kutcher were seen purchasing the family-friendly Lexus sedan late last month.</font>
# end inner loop
# found end_contain parent, exiting loop: <Element font at 0x7f9ddbf90050>
# <font style="font-size:1.2em">The Golden Globe nominee and fianc&#233; Ashton Kutcher were seen purchasing the family-friendly Lexus sedan late last month.</font>
# <font style="font-size:1.2em">The Golden Globe nominee and fianc&#233; Ashton Kutcher were seen purchasing the family-friendly Lexus sedan late last month.</font>
# False
# True
# escape while
# <font style="font-size:1.2em">The Golden Globe nominee and fianc&#233; Ashton Kutcher were seen purchasing the family-friendly Lexus sedan late last month.</font>
# start container
# <font style="font-size:1.2em">New mother Mila Kunis was spotted for the first time since welcoming daughter Wyatt Isabelle in Los Angeles Friday.</font>
# New mother Mila Kunis was spotted for the first time since welcoming daughter Wyatt Isabelle in Los Angeles Friday.
# offset 0
# end container
# <font style="font-size:1.2em">The Golden Globe nominee and fianc&#233; Ashton Kutcher were seen purchasing the family-friendly Lexus sedan late last month.</font>
# The Golden Globe nominee and fiancé Ashton Kutcher were seen purchasing the family-friendly Lexus sedan late last month.
# offset 120
# sc
#  Still has that new car scent: The Golden Globe nominee and fiancé Ashton Kutcher were seen purchasing the family-friendly Lexus sedan late last month
# ec 'Ashton and Mila are both adjusting well': According to the birth certificate, Mila gave birth to their little princess at 1:23AM on October 1 (pictured July 20)
# common
# end inner loop
# end inner loop
# end loop
# <Element div at 0x7f9ddbb37be0>
# [<Element div at 0x7f9ddbb37be0>, <Element div at 0x7f9ddbb374b0>, <Element div at 0x7f9ddbb37050>, <Element div at 0x7f9ddbb379b0>, <Element div at 0x7f9de329c730>, <Element div at 0x7f9de329c7d0>, <Element body at 0x7f9de329cf50>, <Element html at 0x7f9de29c3960>]
# False
# commonacccestor <Element div at 0x7f9ddbb37be0>
# ca's processed children
# start True
# outer loop: <Element p at 0x7f9df80da050>
# <p class="mol-para-with-font"><font style="font-size:1.2em">'He's been so helpful - chipping in for feedings - and he loves to hold the baby.'</font></p>
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# end inner loop
# outer loop: <Element div at 0x7f9de2c55960>
# <div class="mol-img" style="height: auto;">  <img id="i-18ef621acb67a85" src="http://i.dailymail.co.uk/i/pix/2014/10/09/1412895246716_wps_6_EXCLUSIVE_Ashton_Kutcher_.jpg" height="964" width="634" alt="'Ashton and Mila are both adjusting well': According to the birth certificate, Mila gave birth to their little princess at 1:23AM on October 1 (pictured July 20)" class="blkBorder img-share" />
# </div>
# inner loop
# end inner loop
# found end_contain parent, exiting loop: <Element p at 0x7f9de2bfde10>
# <p class="imageCaption">'Ashton and Mila are both adjusting well': According to the birth certificate, Mila gave birth to their little princess at 1:23AM on October 1 (pictured July 20)</p>
# <p class="imageCaption">'Ashton and Mila are both adjusting well': According to the birth certificate, Mila gave birth to their little princess at 1:23AM on October 1 (pictured July 20)</p>
# False
# True
# escape while
# <p class="imageCaption">'Ashton and Mila are both adjusting well': According to the birth certificate, Mila gave birth to their little princess at 1:23AM on October 1 (pictured July 20)</p>
# start container
# <p class="imageCaption">Still has that new car scent: The Golden Globe nominee and fianc&#233; Ashton Kutcher were seen purchasing the family-friendly Lexus sedan late last month</p>
# Still has that new car scent: The Golden Globe nominee and fiancé Ashton Kutcher were seen purchasing the family-friendly Lexus sedan late last month
# offset 0
# end container
# <p class="imageCaption">'Ashton and Mila are both adjusting well': According to the birth certificate, Mila gave birth to their little princess at 1:23AM on October 1 (pictured July 20)</p>
# 'Ashton and Mila are both adjusting well': According to the birth certificate, Mila gave birth to their little princess at 1:23AM on October 1 (pictured July 20)
# offset 168
# sc
#  'I'm excited to be here to introduce my other new baby!' The Two and a Half Men funnyman mentioned his infant daughter at the October 9 launch of the new Lenovo tablet
# ec <Element div at 0x7f9de329c730>
# common
# end inner loop
# end inner loop
# end loop
# <Element div at 0x7f9de329cf50>
# [<Element div at 0x7f9de329cf50>, <Element div at 0x7f9de29c38c0>, <Element div at 0x7f9de29c37d0>, <Element div at 0x7f9de29c3820>, <Element div at 0x7f9de29c3960>, <Element div at 0x7f9df80da050>, <Element body at 0x7f9df80da6e0>, <Element html at 0x7f9ddbb374b0>]
# False
# commonacccestor <Element div at 0x7f9de329cf50>
# ca's processed children
# start True
# outer loop: <Element div at 0x7f9de2c55960>
# <div class="moduleFull mol-video"><div class="item">
#   <div id="v-3831503435001" style="width:636px;">
#   <div class="videoplayer-large" style="overflow-y:hidden">
#     <a>
#       <div class="videoplayer-title-bg"></div>
#       <div class="videoplayer-title">Ashton Kutcher jokes about his daughter in Levono Live stream</div>
#       <div class="btnBg"></div>
#       <span class="playbtn"></span>
#       <center>
#         <img src="http://i.dailymail.co.uk/i/pix/2014/10/10/video-undefined-2218630400000578-583_636x358.jpg" class="plcHlder" />
#       </center>
#     </a>
#   </div>
#   <div class="tvshowbiz">
#     <div class="wocc videoplayer-keyline"></div>
#   </div>
# </div>
# <script type="text/javascript">
#     DM.later('bundle', function(){
#         DM.has('v-3831503435001','BC',
#                 {'renderConfig' :
#                     {
#                         'css' : "videoplayer-large",
#                         'autoplay' : false,
#                         'muted' : false,
#                         'title' : "Ashton Kutcher jokes about his daughter in Levono Live stream",
#                         'videoId' : 1126343,
#                         'adsEnabled' : false,
#                         'playerId' : "1989148206001",
#                         'playerKey' : "AQ~~,AAAAAFSL1bg~,CmS1EFtcMWELN_eSE9A7gpcGWF5XAVmI",
# ...
# </p>
# <p>
# That's not the America, though, that the Republicans refer to in proclaiming their own Americanness. For them, "American" is a term to be used as a wedge issue, a way to distinguish their more racially and religiously homogeneous party from the historically more polyglot Democrats. Such separation has a long pedigree: Campaigning for GOP presidential nominee Alf Landon in 1936, Republican leader Frank Knox said that the Democratic Party under President Franklin Roosevelt "has been seized by alien and un-American elements. Next November, you will choose the American way."
# </p>
# <p>
# Knox meant two things: that the New Deal represented an ideology outside the pale of American thinking and that the New Deal coalition, which represented record numbers of foreign-born, non-Protestant Americans, was therefore un-American. In more recent elections, Republicans have depicted Democratic presidential candidates as un-American cultural elitists heading up a dangerously diverse party.
# </p>
# <p>
# This year, we can expect to see almost nothing but these kinds of assaults as the campaign progresses. The Republican attack against Obama all but ignores the issue differences between the candidates to go after what is presumably his inadequately American identity. He is, writes one leading conservative columnist, "out of touch with everyday America." His reluctance to wear a flag pin, writes another, shows that he "has declared himself superior to an almost universal form of popular patriotism."
# </p>
# <p>
# There are good reasons Republicans are focusing on identity rather than issues this year: In poll after poll, there's not a single major issue on which the public agrees with them or their presumptive nominee. Not Iraq, certainly. Not the economy. Should the election turn on the question of "What are you going to do for America?" rather than "Are you a real American?" Republicans are doomed. They offer no solutions for the stagnation (or decline) of American living standards, or for the weakening of America's economic power. They offer no resolution to America's war of choice in Iraq. Their party leader, the incumbent president, let a great American city drown. They are the American party, and McCain the American nominee, that hasn't a clue about how to help America in its (prolonged, I fear) moment of need.
# </p>
# <p>
# What remains for the GOP is a campaign premised more on issues of national identity, aimed largely at that portion of our population for which "American" is synonymous with "white" and "Christian," than any national campaign has been since the American Party (also known as the Know Nothings) based its 1856 campaign chiefly on Protestant bigotry against Irish and German Catholic immigrants. In Appalachian America (the heart of which went to the polls yesterday in West Virginia), as Mark Schmitt notes in the forthcoming issue of the American Prospect (which I edit), a disproportionate number of people write "American" when answering the census question on ethnic origin. For some, "American" is a race -- white -- no less than a nationality, and it's on this equation that Republican prospects depend.
# </p>
# <p>
# Which is why Gilbert and Sullivan penned what could be the perfect McCain marching song:
# </p>
# <p>
# <i>But in spite of all temptations<br/></i><i>To belong to other nations,</i><i><br/></i><i>He remains American!</i><i><br/></i><i>He remains American!</i>
# </p>
# <p>
# <i><a href="mailto:meyersonh@washpost.com">meyersonh@washpost.com</a></i>
# </p>
# </div>
# </div>
#
# end inner loop
# outer loop: <Element p at 0x7f9ddbcb4a50>
# <p>
# If the McCain campaign is still trying out songs, there's one by a couple of Brits, W.S. Gilbert and Arthur Sullivan, that it should consider. We have to change the words "an Englishman" to "American" to get it to work, but, that done, the song expresses succinctly and entirely the case for John McCain and, by implication, against Barack Obama:
# </p>
#
# end inner loop
# found end_contain parent, exiting loop: <Element p at 0x7f9ddbcb4a50>
# <p>
# If the McCain campaign is still trying out songs, there's one by a couple of Brits, W.S. Gilbert and Arthur Sullivan, that it should consider. We have to change the words "an Englishman" to "American" to get it to work, but, that done, the song expresses succinctly and entirely the case for John McCain and, by implication, against Barack Obama:
# </p>
#
# error
# downloads_id 582829721
# {u'end_offset': 0, u'end_xpath': u'/html[1]/body[1]/div[2]/div[2]/div[1]/div[1]/div[2]/div[3]/p[1]', u'start_offset': 0, u'start_xpath': u'/html[1]/body[1]/div[2]/div[2]/div[1]/div[1]/div[2]/div[2]/font[1]/div[1]/text()[1]'}
# skipped 72
# processed 28
# sc Volatility on the markets is normal. Long live volatility! And, this week my thoughts returned to  turbulent stock markets around the globe. It does not seem so long ago that the equity markets on the major indexes were in rude form and hitting news highs. Then the wheels seemed to fall off the wagon in recent weeks with the Dow Jones Industrial Average (DJIA) and S&P 500 amongst other blue-chip benchmarks getting the jitters.
# ec At the end of the day while there is a lot fancy talk around investing and how to do it, fundamentally it revolves around three basic things: what to buy, when to buy and when to sell. Some investors will see the latest level on the Dow as a good buying opportunity to top up their existing holdings. But caveat emptor.
# common
# end inner loop
# end loop
# <Element div at 0x7f9de01c8af0>
# [<Element div at 0x7f9de01c8af0>, <Element div at 0x7f9de01c84b0>, <Element div at 0x7f9de01c85a0>, <Element div at 0x7f9de01c8c30>, <Element section at 0x7f9de01c8320>, <Element div at 0x7f9de01c8d20>, <Element body at 0x7f9de01c8820>, <Element html at 0x7f9de01c8410>]
# False
# commonacccestor <Element div at 0x7f9de01c8af0>
# ca's processed children
# start True
# outer loop: <Element p at 0x7f9e01b746e0>
# <p>As recently as 23 July &#8211; just under three months ago &#8211; Jaco Rouw, Core FI Investment Manager at ING Investment&#160;Management, discussing how FX volatility was reaching new lows stated: &#8220;Going forward, there is always the possibility of shocks that will drive volatility higher. Apart from this, the current level of volatility seems justifiable and might stay at low levels in the near term.&#8221;</p>
#
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# end inner loop
# found end_contain parent, exiting loop: <Element p at 0x7f9de01c8f00>
# <p>At the end of the day while there is a lot fancy talk around investing and how to do it, fundamentally it revolves around three basic things: what to buy, when to buy and when to sell. Some investors will see the latest level on the Dow as a good buying opportunity to top up their existing holdings. But caveat emptor.</p>
#
#
#
# <p>At the end of the day while there is a lot fancy talk around investing and how to do it, fundamentally it revolves around three basic things: what to buy, when to buy and when to sell. Some investors will see the latest level on the Dow as a good buying opportunity to top up their existing holdings. But caveat emptor.</p>
#
#
#
# False
# True
# escape while
# <p>At the end of the day while there is a lot fancy talk around investing and how to do it, fundamentally it revolves around three basic things: what to buy, when to buy and when to sell. Some investors will see the latest level on the Dow as a good buying opportunity to top up their existing holdings. But caveat emptor.</p>
#
#
#
# start container
# <p>Volatility on the markets is normal. Long live volatility! And, this week my thoughts returned to &#160;turbulent stock markets around the globe. It does not seem so long ago that the equity markets on the major indexes were in rude form and hitting news highs. Then the wheels seemed to fall off the wagon in recent weeks with the Dow Jones Industrial Average (DJIA) and S&amp;P 500 amongst other blue-chip benchmarks getting the jitters.</p>
#
# Volatility on the markets is normal. Long live volatility! And, this week my thoughts returned to  turbulent stock markets around the globe. It does not seem so long ago that the equity markets on the major indexes were in rude form and hitting news highs. Then the wheels seemed to fall off the wagon in recent weeks with the Dow Jones Industrial Average (DJIA) and S&P 500 amongst other blue-chip benchmarks getting the jitters.
# offset 0
# end container
# <p>At the end of the day while there is a lot fancy talk around investing and how to do it, fundamentally it revolves around three basic things: what to buy, when to buy and when to sell. Some investors will see the latest level on the Dow as a good buying opportunity to top up their existing holdings. But caveat emptor.</p>
#
#
#
# At the end of the day while there is a lot fancy talk around investing and how to do it, fundamentally it revolves around three basic things: what to buy, when to buy and when to sell. Some investors will see the latest level on the Dow as a good buying opportunity to top up their existing holdings. But caveat emptor.
# offset 319
# sc
#  A
# ec . Frank Sinatra, Dean Martin, Tony Curtis and Ray Charles were some of their neighbors at the time. That home sold for $14.5 million in March.
# common
# end inner loop
# end loop
# <Element div at 0x7f9de29bcd20>
# [<Element div at 0x7f9de29bcd20>, <Element div at 0x7f9de29bc6e0>, <Element div at 0x7f9de29bc140>, <Element div at 0x7f9de29bc960>, <Element section at 0x7f9de29bc4b0>, <Element div at 0x7f9de29bc9b0>, <Element body at 0x7f9de29bca50>, <Element html at 0x7f9de01c8c80>]
# False
# commonacccestor <Element div at 0x7f9de29bcd20>
# ca's processed children
# start True
# outer loop: <Element p at 0x7f9de29bce60>
# <p>The home, referred to as &#8220;Graceland West&#8221; by The New York Times, was built in 1946. Elvis and his wife Priscilla purchased it in 1970. When the couple divorced in 1973, the home was turned into more of a &#8220;boys&#8217; club&#8221; for Elvis, according to agent Eric Meeks, who previously listed the house. Presley built a new master suite to avoid sleeping in the room he shared with Priscilla.</p>
#
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# inner loop
# end inner loop
# outer loop: <Element a at 0x7f9de29bc0a0>
# <a href="http://www.zillow.com/blog/elvis-beverly-hills-home-for-sale-100814/">Beverly Hills home in the renowned Trousdale Estates</a>. Frank Sinatra, Dean Martin, Tony Curtis and Ray Charles were some of their neighbors at the time.&#160;That home sold for $14.5 million in March.
# end inner loop
# found end_contain parent, exiting loop: <Element a at 0x7f9de29bc0a0>
# <a href="http://www.zillow.com/blog/elvis-beverly-hills-home-for-sale-100814/">Beverly Hills home in the renowned Trousdale Estates</a>. Frank Sinatra, Dean Martin, Tony Curtis and Ray Charles were some of their neighbors at the time.&#160;That home sold for $14.5 million in March.
# <a href="http://www.zillow.com/blog/elvis-beverly-hills-home-for-sale-100814/">Beverly Hills home in the renowned Trousdale Estates</a>. Frank Sinatra, Dean Martin, Tony Curtis and Ray Charles were some of their neighbors at the time.&#160;That home sold for $14.5 million in March.
# True
# False
# escape while
# <a href="http://www.zillow.com/blog/elvis-beverly-hills-home-for-sale-100814/">Beverly Hills home in the renowned Trousdale Estates</a>. Frank Sinatra, Dean Martin, Tony Curtis and Ray Charles were some of their neighbors at the time.&#160;That home sold for $14.5 million in March.
# start container
# <p>A <a href="http://www.zillow.com/blog/elvis-graceland-west-144177/">Palm Springs resort home</a> once owned by Elvis Presley is going to auction.</p>
#
# A
# offset 0
# end container
# <a href="http://www.zillow.com/blog/elvis-beverly-hills-home-for-sale-100814/">Beverly Hills home in the renowned Trousdale Estates</a>. Frank Sinatra, Dean Martin, Tony Curtis and Ray Charles were some of their neighbors at the time.&#160;That home sold for $14.5 million in March.
# . Frank Sinatra, Dean Martin, Tony Curtis and Ray Charles were some of their neighbors at the time. That home sold for $14.5 million in March.
# offset 142
# sc
#  Use OS X 10.10 Yosemite to place, receive phone calls
# ec As part of Apple's Continuity efforts, you can now leverage your nearby iPhone to place, receive phone calls from your Mac.
# common
# end inner loop
# end loop
# <Element article at 0x7f9de0062280>
# [<Element article at 0x7f9de0062280>, <Element div at 0x7f9de29bc7d0>, <Element div at 0x7f9de00c4dc0>, <Element div at 0x7f9de00c45f0>, <Element div at 0x7f9de327b320>, <Element div at 0x7f9de240d3c0>, <Element div at 0x7f9de240dd70>, <Element div at 0x7f9de240d550>, <Element div at 0x7f9de240d410>, <Element div at 0x7f9de240d7d0>, <Element div at 0x7f9de240dbe0>, <Element body at 0x7f9de240d370>, <Element html at 0x7f9de01c89b0>]
# False
# commonacccestor <Element article at 0x7f9de0062280>
# ca's processed children
# start True
# outer loop: <Element p at 0x7f9de01c8280>
# <p class="article-dek" itemprop="description">As part of Apple's Continuity efforts, you can now leverage your nearby iPhone to place, receive phone calls from your Mac.</p>
#
#
#
# end inner loop
# found end_contain parent, exiting loop: <Element p at 0x7f9de01c8280>
# <p class="article-dek" itemprop="description">As part of Apple's Continuity efforts, you can now leverage your nearby iPhone to place, receive phone calls from your Mac.</p>
#
#
#
# <p class="article-dek" itemprop="description">As part of Apple's Continuity efforts, you can now leverage your nearby iPhone to place, receive phone calls from your Mac.</p>
#
#
#
# False
# True
# escape while
# <p class="article-dek" itemprop="description">As part of Apple's Continuity efforts, you can now leverage your nearby iPhone to place, receive phone calls from your Mac.</p>
#
#
#
# start container
# <h1 itemprop="headline">Use OS X 10.10 Yosemite to place, receive phone calls</h1>
#
# Use OS X 10.10 Yosemite to place, receive phone calls
# offset 0
# end container
# <p class="article-dek" itemprop="description">As part of Apple's Continuity efforts, you can now leverage your nearby iPhone to place, receive phone calls from your Mac.</p>
#
#
#
# As part of Apple's Continuity efforts, you can now leverage your nearby iPhone to place, receive phone calls from your Mac.
# offset 123
# error
# downloads_id 582815971
# {u'end_offset': 28, u'end_xpath': u'/html[1]/body[1]/div[2]/div[1]/div[1]/div[3]/div[2]/div[1]/div[1]/div[1]/div[1]/div[1]/article[1]/div[2]/ul[1]/li[2]/time[1]/text()[1]', u'start_offset': 0, u'start_xpath': u'/html[1]/body[1]/div[2]/div[1]/div[1]/div[3]/div[2]/div[1]/div[1]/div[1]/div[1]/div[1]/article[1]/div[2]/ul[1]/li[2]/time[1]/text()[1]'}
# sc
#  By
# ec Lorena Mongelli
# common
# end loop
# <Element p at 0x7f9de327b320>
# [<Element p at 0x7f9de327b320>, <Element div at 0x7f9de01c81e0>, <Element div at 0x7f9de01c8370>, <Element div at 0x7f9de01c85f0>, <Element div at 0x7f9de01c8230>, <Element div at 0x7f9de01c8f50>, <Element div at 0x7f9de01c8960>, <Element div at 0x7f9de01c8460>, <Element div at 0x7f9de01c8be0>, <Element body at 0x7f9de01c80a0>, <Element html at 0x7f9de00627d0>]
# False
# commonacccestor <Element p at 0x7f9de327b320>
# ca's processed children
# error
# downloads_id 582816376
# {u'end_offset': 14, u'end_xpath': u'/html[1]/body[1]/div[3]/div[3]/div[2]/div[1]/div[2]/div[1]/div[1]/div[2]/p[1]/a[3]/text()[1]', u'start_offset': 0, u'start_xpath': u'/html[1]/body[1]/div[3]/div[3]/div[2]/div[1]/div[2]/div[1]/div[1]/div[2]/p[1]/text()[1]'}
# error
# downloads_id 582816466
# {u'end_offset': 54, u'end_xpath': u'/html[1]/body[1]/div[2]/div[1]/div[2]/div[1]/div[1]/article[1]/header[1]/h1[1]/text()[2]', u'start_offset': 0, u'start_xpath': u'/html[1]/body[1]/div[2]/div[1]/div[2]/div[1]/div[1]/article[1]/header[1]/h1[1]/text()[1]'}
# skipped 3
# processed 2

# %%
eto = extractor_training_objects[ 0 ]
print eto.keys()
print 'http://127.0.0.1:5000/extractor_train/' + str(eto['downloads_id'])
print eto['story']['url']
print eto['expected_lines']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-244-5d4ed76fed8a> in <module>()
# ----> 1 eto = extractor_training_objects[ 0 ]
#       2 print eto.keys()
#       3 print 'http://127.0.0.1:5000/extractor_train/' + str(eto['downloads_id'])
#       4 print eto['story']['url']
#       5 print eto['expected_lines']
#
# IndexError: list index out of range

# %%
print len( extractor_training_objects )

comps_new_downloads = []
for extractor_training_object in extractor_training_objects:
    res = comp_extractors( extractor_training_object )
    #print res
    comps_new_downloads.append( res )

#extractor_training_objects
# Out:
# 28
# [326, 327, 467, 468, 469, 476, 477, 478, 541, 572, 599]
# [310, 326, 599]
# original article tmp file
#  /tmp/tmpv97p2i.html
# /tmp/tmpvLzoww.html
# /tmp/tmpv97p2i.html
# /tmp/tmpv97p2i.html
# Now open file:///tmp/tmpvLzoww.html in your web browser
# Unexpected error on string '
# ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# '
#  <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# '
#  <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# '
#  <class 'lxml.etree.ParserError'>
# [326, 327, 467, 468, 469, 476, 477, 478, 541, 572, 599]
# [310, 326, 599]
# original article tmp file
#  /tmp/tmp7lDQab.html
# /tmp/tmp7pfALt.html
# /tmp/tmp7lDQab.html
# /tmp/tmp7lDQab.html
# Now open file:///tmp/tmp7pfALt.html in your web browser
# Unexpected error on string '
# ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#
# ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# '
#  <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#
# ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#
# ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# '
#  <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#
# ' <class 'lxml.etree.ParserError'>
# [326, 327, 467, 468, 469, 476, 477, 478, 541, 572, 599]
# [310, 326, 599]
# original article tmp file
#  /tmp/tmpOTqd4G.html
# /tmp/tmphKmDA3.html
# /tmp/tmpOTqd4G.html
# /tmp/tmpOTqd4G.html
# Now open file:///tmp/tmphKmDA3.html in your web browser
# Unexpected error on string '
#         ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#         '
#  <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#         '
#  <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#         '
#  <class 'lxml.etree.ParserError'>
# [326, 327, 467, 468, 469, 476, 477, 478, 541, 572, 599]
# [310, 326, 599]
# original article tmp file
#  /tmp/tmpIc0Adv.html
# /tmp/tmpbnGIt3.html
# /tmp/tmpIc0Adv.html
# /tmp/tmpIc0Adv.html
# Now open file:///tmp/tmpbnGIt3.html in your web browser
# Unexpected error on string '  ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '   ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '   ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# 	' <class 'lxml.etree.ParserError'>
# Unexpected error on string '  '
#  <class 'lxml.etree.ParserError'>
# Unexpected error on string '   ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '   ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# 	' <class 'lxml.etree.ParserError'>
# Unexpected error on string '  ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '   ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '   ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# 	' <class 'lxml.etree.ParserError'>
# Unexpected error on string '  '
#  <class 'lxml.etree.ParserError'>
# Unexpected error on string '   ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '   ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# 	' <class 'lxml.etree.ParserError'>
# [326, 327, 467, 468, 469, 476, 477, 478, 541, 572, 599]
# [310, 326, 599]
# original article tmp file
#  /tmp/tmp_djrGn.html
# /tmp/tmpqUV82i.html
# /tmp/tmp_djrGn.html
# /tmp/tmp_djrGn.html
# Now open file:///tmp/tmpqUV82i.html in your web browser
# Unexpected error on string '
#     ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#     '
#  <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#     ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#     '
#  <class 'lxml.etree.ParserError'>
# [326, 327, 467, 468, 469, 476, 477, 478, 541, 572, 599]
# [310, 326, 599]
# original article tmp file
#  /tmp/tmpKxU6Qc.html
# /tmp/tmpe76PGc.html
# /tmp/tmpKxU6Qc.html
# /tmp/tmpKxU6Qc.html
# Now open file:///tmp/tmpe76PGc.html in your web browser
# Unexpected error on string '
#         ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#         '
#  <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#         ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#         '
#  <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# ' <class 'lxml.etree.ParserError'>
# [326, 327, 467, 468, 469, 476, 477, 478, 541, 572, 599]
# [310, 326, 599]
# original article tmp file
#  /tmp/tmp3L0y6F.html
# /tmp/tmpjWEJEG.html
# /tmp/tmp3L0y6F.html
# /tmp/tmp3L0y6F.html
# Now open file:///tmp/tmpjWEJEG.html in your web browser
# Unexpected error on string '
#   ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '   ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '   ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '   ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '   ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '   ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '   ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#   '
#  <class 'lxml.etree.ParserError'>
# Unexpected error on string '   ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '   ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '   ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '   ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '   ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '   ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#   '
#  <class 'lxml.etree.ParserError'>
# Unexpected error on string '   ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '   ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '   ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '   ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '   ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '   ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#   '
#  <class 'lxml.etree.ParserError'>
# Unexpected error on string '   ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '   ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '   ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '   ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '   ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '   ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# ' <class 'lxml.etree.ParserError'>
# [326, 327, 467, 468, 469, 476, 477, 478, 541, 572, 599]
# [310, 326, 599]
# original article tmp file
#  /tmp/tmpJ6kgEN.html
# /tmp/tmpIdjKo1.html
# /tmp/tmpJ6kgEN.html
# /tmp/tmpJ6kgEN.html
# Now open file:///tmp/tmpIdjKo1.html in your web browser
# Unexpected error on string '
#
#     ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#         ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#         ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#         ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#
#     '
#  <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#         ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#         ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#         ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#
#     '
#  <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#         ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#         ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#         ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#
#     '
#  <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#         ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#         ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#         ' <class 'lxml.etree.ParserError'>
# [326, 327, 467, 468, 469, 476, 477, 478, 541, 572, 599]
# [310, 326, 599]
# original article tmp file
#  /tmp/tmpw7jTac.html
# /tmp/tmpviuAZt.html
# /tmp/tmpw7jTac.html
# /tmp/tmpw7jTac.html
# Now open file:///tmp/tmpviuAZt.html in your web browser
# Unexpected error on string '  ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '  '
#  <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '  ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '  '
#  <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# ' <class 'lxml.etree.ParserError'>
# [326, 327, 467, 468, 469, 476, 477, 478, 541, 572, 599]
# [310, 326, 599]
# original article tmp file
#  /tmp/tmpZQ4XHk.html
# /tmp/tmpToZHYs.html
# /tmp/tmpZQ4XHk.html
# /tmp/tmpZQ4XHk.html
# Now open file:///tmp/tmpToZHYs.html in your web browser
# [326, 327, 467, 468, 469, 476, 477, 478, 541, 572, 599]
# [310, 326, 599]
# original article tmp file
#  /tmp/tmpZcqZSM.html
# /tmp/tmpzG8Y_s.html
# /tmp/tmpZcqZSM.html
# /tmp/tmpZcqZSM.html
# Now open file:///tmp/tmpzG8Y_s.html in your web browser
# Unexpected error on string '
#
#     ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#         ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#         ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#         ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#
#     ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#         ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#         ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#         ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#
#     '
#  <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#         ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#         ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#         ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#
#     '
#  <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#         ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#         ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#         ' <class 'lxml.etree.ParserError'>
# [326, 327, 467, 468, 469, 476, 477, 478, 541, 572, 599]
# [310, 326, 599]
# original article tmp file
#  /tmp/tmpkXH7hf.html
# /tmp/tmpBKHTOI.html
# /tmp/tmpkXH7hf.html
# /tmp/tmpkXH7hf.html
# Now open file:///tmp/tmpBKHTOI.html in your web browser
# [326, 327, 467, 468, 469, 476, 477, 478, 541, 572, 599]
# [310, 326, 599]
# original article tmp file
#  /tmp/tmpe1dkaQ.html
# /tmp/tmpF5nlRu.html
# /tmp/tmpe1dkaQ.html
# /tmp/tmpe1dkaQ.html
# Now open file:///tmp/tmpF5nlRu.html in your web browser
# Unexpected error on string '  ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '  '
#  <class 'lxml.etree.ParserError'>
# Unexpected error on string '  ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '  '
#  <class 'lxml.etree.ParserError'>
# [326, 327, 467, 468, 469, 476, 477, 478, 541, 572, 599]
# [310, 326, 599]
# original article tmp file
#  /tmp/tmpmxabn1.html
# /tmp/tmp0GNw6e.html
# /tmp/tmpmxabn1.html
# /tmp/tmpmxabn1.html
# Now open file:///tmp/tmp0GNw6e.html in your web browser
# Unexpected error on string '
#         ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#     ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#           ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#         '
#  <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#     ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#           ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#         '
#  <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#     ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#           ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#         '
#  <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#     ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#           ' <class 'lxml.etree.ParserError'>
# [326, 327, 467, 468, 469, 476, 477, 478, 541, 572, 599]
# [310, 326, 599]
# original article tmp file
#  /tmp/tmpsg_6Q4.html
# /tmp/tmpQ2QfC8.html
# /tmp/tmpsg_6Q4.html
# /tmp/tmpsg_6Q4.html
# Now open file:///tmp/tmpQ2QfC8.html in your web browser
# [326, 327, 467, 468, 469, 476, 477, 478, 541, 572, 599]
# [310, 326, 599]
# original article tmp file
#  /tmp/tmplV0unr.html
# /tmp/tmpKBzWOB.html
# /tmp/tmplV0unr.html
# /tmp/tmplV0unr.html
# Now open file:///tmp/tmpKBzWOB.html in your web browser
# Unexpected error on string '
#     ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#     '
#  <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#     '
#  <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#     '
#  <class 'lxml.etree.ParserError'>
# [326, 327, 467, 468, 469, 476, 477, 478, 541, 572, 599]
# [310, 326, 599]
# original article tmp file
#  /tmp/tmpxDEXrt.html
# /tmp/tmp2fl4MV.html
# /tmp/tmpxDEXrt.html
# /tmp/tmpxDEXrt.html
# Now open file:///tmp/tmp2fl4MV.html in your web browser
# [326, 327, 467, 468, 469, 476, 477, 478, 541, 572, 599]
# [310, 326, 599]
# original article tmp file
#  /tmp/tmpX9zyLY.html
# /tmp/tmpx5qM9o.html
# /tmp/tmpX9zyLY.html
# /tmp/tmpX9zyLY.html
# Now open file:///tmp/tmpx5qM9o.html in your web browser
# Unexpected error on string '
# 				' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# 					' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# 				'
#  <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# 					' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# 				'
#  <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# 					' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# 				'
#  <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# 					' <class 'lxml.etree.ParserError'>
# [326, 327, 467, 468, 469, 476, 477, 478, 541, 572, 599]
# [310, 326, 599]
# original article tmp file
#  /tmp/tmpKk3Y3e.html
# /tmp/tmp0yuVsI.html
# /tmp/tmpKk3Y3e.html
# /tmp/tmpKk3Y3e.html
# Now open file:///tmp/tmp0yuVsI.html in your web browser
# Unexpected error on string '
#         ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#     ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#           ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#         '
#  <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#     ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#           ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#         '
#  <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#     ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#           ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#         '
#  <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#     ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#           ' <class 'lxml.etree.ParserError'>
# [326, 327, 467, 468, 469, 476, 477, 478, 541, 572, 599]
# [310, 326, 599]
# original article tmp file
#  /tmp/tmpZmnLZS.html
# /tmp/tmpMk1NnR.html
# /tmp/tmpZmnLZS.html
# /tmp/tmpZmnLZS.html
# Now open file:///tmp/tmpMk1NnR.html in your web browser
# Unexpected error on string '
#         ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#     ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#           ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#         '
#  <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#     ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#           ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#         ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#     ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#           ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#         '
#  <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#     ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#           ' <class 'lxml.etree.ParserError'>
# [326, 327, 467, 468, 469, 476, 477, 478, 541, 572, 599]
# [310, 326, 599]
# original article tmp file
#  /tmp/tmpdVi6MJ.html
# /tmp/tmpLLu_go.html
# /tmp/tmpdVi6MJ.html
# /tmp/tmpdVi6MJ.html
# Now open file:///tmp/tmpLLu_go.html in your web browser
# Unexpected error on string '      ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '        ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '      '
#  <class 'lxml.etree.ParserError'>
# Unexpected error on string '        ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '      '
#  <class 'lxml.etree.ParserError'>
# Unexpected error on string '        ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '      '
#  <class 'lxml.etree.ParserError'>
# Unexpected error on string '        ' <class 'lxml.etree.ParserError'>
# [326, 327, 467, 468, 469, 476, 477, 478, 541, 572, 599]
# [310, 326, 599]
# original article tmp file
#  /tmp/tmp3ovzOR.html
# /tmp/tmpU742wg.html
# /tmp/tmp3ovzOR.html
# /tmp/tmp3ovzOR.html
# Now open file:///tmp/tmpU742wg.html in your web browser
# Unexpected error on string '      ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '        ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '      '
#  <class 'lxml.etree.ParserError'>
# Unexpected error on string '        ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '      ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '        ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '      '
#  <class 'lxml.etree.ParserError'>
# Unexpected error on string '        ' <class 'lxml.etree.ParserError'>
# [326, 327, 467, 468, 469, 476, 477, 478, 541, 572, 599]
# [310, 326, 599]
# original article tmp file
#  /tmp/tmpJuEymC.html
# /tmp/tmp89G7Dc.html
# /tmp/tmpJuEymC.html
# /tmp/tmpJuEymC.html
# Now open file:///tmp/tmp89G7Dc.html in your web browser
# Unexpected error on string '
# ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# 					' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# '
#  <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# 					' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# '
#  <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# 					' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# '
#  <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# 					' <class 'lxml.etree.ParserError'>
# [326, 327, 467, 468, 469, 476, 477, 478, 541, 572, 599]
# [310, 326, 599]
# original article tmp file
#  /tmp/tmpgaHRSD.html
# /tmp/tmpPumPea.html
# /tmp/tmpgaHRSD.html
# /tmp/tmpgaHRSD.html
# Now open file:///tmp/tmpPumPea.html in your web browser
# [326, 327, 467, 468, 469, 476, 477, 478, 541, 572, 599]
# [310, 326, 599]
# original article tmp file
#  /tmp/tmpuXFb4d.html
# /tmp/tmpYrX88W.html
# /tmp/tmpuXFb4d.html
# /tmp/tmpuXFb4d.html
# Now open file:///tmp/tmpYrX88W.html in your web browser
# Unexpected error on string '      ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '        ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '      '
#  <class 'lxml.etree.ParserError'>
# Unexpected error on string '        ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '      ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '        ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '      '
#  <class 'lxml.etree.ParserError'>
# Unexpected error on string '        ' <class 'lxml.etree.ParserError'>
# [326, 327, 467, 468, 469, 476, 477, 478, 541, 572, 599]
# [310, 326, 599]
# original article tmp file
#  /tmp/tmpgn0JLj.html
# /tmp/tmpwuF7GX.html
# /tmp/tmpgn0JLj.html
# /tmp/tmpgn0JLj.html
# Now open file:///tmp/tmpwuF7GX.html in your web browser
# Unexpected error on string '
#         ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#     ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#           ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#         '
#  <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#     ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#           ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#         '
#  <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#     ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#           ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#         '
#  <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#     ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#           ' <class 'lxml.etree.ParserError'>
# [326, 327, 467, 468, 469, 476, 477, 478, 541, 572, 599]
# [310, 326, 599]
# original article tmp file
#  /tmp/tmpVGx4Hc.html
# /tmp/tmpn6hgoa.html
# /tmp/tmpVGx4Hc.html
# /tmp/tmpVGx4Hc.html
# Now open file:///tmp/tmpn6hgoa.html in your web browser
# Unexpected error on string '
# ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#         ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# '
#  <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#         ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# '
#  <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#         ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# '
#  <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#         ' <class 'lxml.etree.ParserError'>
# [326, 327, 467, 468, 469, 476, 477, 478, 541, 572, 599]
# [310, 326, 599]
# original article tmp file
#  /tmp/tmpGXzE_L.html
# /tmp/tmpIb3k7f.html
# /tmp/tmpGXzE_L.html
# /tmp/tmpGXzE_L.html
# Now open file:///tmp/tmpIb3k7f.html in your web browser
# Unexpected error on string '
# ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#     ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#
#
#
#
#
#
#
#                                             ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# '
#  <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#     ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#
#
#
#
#
#
#
#                                             ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# '
#  <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#     ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#
#
#
#
#
#
#
#                                             ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
# '
#  <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#     ' <class 'lxml.etree.ParserError'>
# Unexpected error on string '
#
#
#
#
#
#
#
#                                             ' <class 'lxml.etree.ParserError'>

# %%
import pandas as pd



new_comps = []
for comp in comps:
    new_comp = {}
    new_comp = { 'downloads_id': comp['downloads_id'] }
    #del comp['downloads_id']
    
    extractor_types = [ k for k in comp.keys() if k != 'downloads_id' ]
    
    for extractor_type in extractor_types:
        new_comp.update([ ( k + '_' + extractor_type , v) for k,v in comp[ extractor_type ].iteritems() ])
        #new_comp[ k + 'boiler_pipe      

    new_comps.append( new_comp )
    
new_comps
df = pd.DataFrame( new_comps )
df.set_index('downloads_id', inplace=True )
df.describe(percentiles=[.5] )
result_types = [ 'precision', 'recall', 'f1' ]
for result_type in result_types:
    res_columns = [ col for col in df.columns if col.startswith( result_type ) ]
    #df.ix[:,['f1_boiler_pipe',	'f1_crf',	'f1_heur', 'f1_python_readibilty']].describe()
    print df.ix[:,res_columns].describe( percentiles=[0.5])
#df.describe()
# Out:
#        precision_boiler_pipe  precision_crf  precision_heur  \
# count              10.000000      10.000000       10.000000
# mean                0.739779       0.787245        0.710740
# std                 0.284824       0.373434        0.257586
# min                 0.026814       0.060606        0.181963
# 50%                 0.810234       0.991935        0.743933
# max                 0.979695       1.000000        1.000000
#
#        precision_py_goose  precision_python_readibilty
# count           10.000000                    10.000000
# mean             0.982540                     0.966188
# std              0.037184                     0.037156
# min              0.901538                     0.892601
# 50%              1.000000                     0.976836
# max              1.000000                     1.000000
#        recall_boiler_pipe  recall_crf  recall_heur  recall_py_goose  \
# count           10.000000   10.000000    10.000000        10.000000
# mean             0.775660    0.589271     0.928525         0.628317
# std              0.300060    0.455324     0.041151         0.362118
# min              0.097421    0.022140     0.872690         0.054441
# 50%              0.850219    0.843700     0.933424         0.742309
# max              0.991786    1.000000     0.982808         0.978261
#
#        recall_python_readibilty
# count                 10.000000
# mean                   0.967279
# std                    0.040878
# min                    0.880531
# 50%                    0.980334
# max                    1.000000
#        f1_boiler_pipe     f1_crf    f1_heur  f1_py_goose  f1_python_readibilty
# count       10.000000  10.000000  10.000000    10.000000             10.000000
# mean         0.746430   0.606308   0.774217     0.696688              0.965652
# std          0.292286   0.433827   0.203908     0.332937              0.020444
# min          0.042053   0.043321   0.307073     0.103261              0.934272
# 50%          0.821974   0.849403   0.811091     0.825273              0.968270
# max          0.984694   0.991329   0.973913     0.989011              0.988806

# %%
df.describe()
# Out:
#        f1_boiler_pipe    f1_crf   f1_heur  f1_python_readibilty  \
# count        1.000000  1.000000  1.000000              1.000000
# mean         0.713675  0.846652  0.898824              0.941176
# std               NaN       NaN       NaN                   NaN
# min          0.713675  0.846652  0.898824              0.941176
# 25%          0.713675  0.846652  0.898824              0.941176
# 50%          0.713675  0.846652  0.898824              0.941176
# 75%          0.713675  0.846652  0.898824              0.941176
# max          0.713675  0.846652  0.898824              0.941176
#
#        precision_boiler_pipe  precision_crf  precision_heur  \
# count               1.000000       1.000000        1.000000
# mean                0.613971       0.734082        0.834061
# std                      NaN            NaN             NaN
# min                 0.613971       0.734082        0.834061
# 25%                 0.613971       0.734082        0.834061
# 50%                 0.613971       0.734082        0.834061
# 75%                 0.613971       0.734082        0.834061
# max                 0.613971       0.734082        0.834061
#
#        precision_python_readibilty  recall_boiler_pipe  recall_crf  \
# count                      1.00000            1.000000           1
# mean                       0.94359            0.852041           1
# std                            NaN                 NaN         NaN
# min                        0.94359            0.852041           1
# 25%                        0.94359            0.852041           1
# 50%                        0.94359            0.852041           1
# 75%                        0.94359            0.852041           1
# max                        0.94359            0.852041           1
#
#        recall_heur  recall_python_readibilty
# count      1.00000                  1.000000
# mean       0.97449                  0.938776
# std            NaN                       NaN
# min        0.97449                  0.938776
# 25%        0.97449                  0.938776
# 50%        0.97449                  0.938776
# 75%        0.97449                  0.938776
# max        0.97449                  0.938776

# %%
res = compare_extractors_for_download( 461179954 )
res
# Out:
# [190, 191, 192, 193, 194, 195, 196, 197]
# [190, 191, 192, 193, 194, 195, 196, 197, 953, 954, 955, 956, 957, 958, 959, 960, 961, 962, 1157, 1158, 1159, 1160, 1161, 1162, 1163, 1172, 1174, 1175, 1176, 1177, 1178, 1179, 1180, 1189, 1191, 1192, 1193, 1194, 1195, 1306, 1307, 1308, 1309, 1310, 1311, 1312, 1313, 1314, 1315, 2402, 2403, 2404, 2405, 2406, 2407, 2408, 2409, 2410, 2411, 2412, 2769, 2770, 2771, 2772, 2773, 2774, 2775, 2776, 2777, 2778, 2779, 2780, 2781, 2782, 2783, 2784, 2785, 3503, 3504, 3505, 3506, 3507, 3508, 3509, 3510, 3569, 3570, 3571, 3572, 3573]
# [181, 182, 190, 191, 192, 193, 194, 195, 196, 197]
# original article tmp file
#  /tmp/tmp5i6pzQ.html
# /tmp/tmpSdaJ4b.html
# /tmp/tmp5i6pzQ.html
# /tmp/tmp5i6pzQ.html
# Now open file:///tmp/tmpSdaJ4b.html in your web browser
# {'boiler_pipe': {'f1': 0.05381484592027909,
#   'precision': 0.027653288185107726,
#   'recall': 0.9976047904191617},
#  'crf': {'f1': 0.3154066985645933,
#   'precision': 0.1876993166287016,
#   'recall': 0.9868263473053892},
#  'downloads_id': 461179954,
#  'heur': {'f1': 0.9933694996986137,
#   'precision': 1.0,
#   'recall': 0.9868263473053892},
#  'python_readibilty': {'f1': 0.2412060301507538,
#   'precision': 0.3010752688172043,
#   'recall': 0.20119760479041915}}

# %%
def gen_data(downloads_id, included_line_numbers):
    
    heuristic_training_ip = []
    c_t_ip = []
    h_t_ip = []
    
    try:
        
        #api_key = ''
        loc_key = api_key
    
        download = requests.get('https://api.mediacloud.org/api/v2/downloads/single/'+str(downloads_id)+'?key='+api_key)
        raw_content = download.json()[0][u'raw_content']
        stories_id = download.json()[0][u'stories_id']
    
        story = requests.get('https://api.mediacloud.org/api/v2/stories/single/'+str(stories_id)+'?key='+api_key)
        title = story.json()[0][u'title']
        description = story.json()[0][u'description']
        url = story.json()[0][u'url']

        story_lines_params = {'key':loc_key, 'body_html':raw_content}
        
        headers = {'Content-type': 'application/json'}
        story_lines = requests.put('https://api.mediacloud.org/api/v2/extractlines/story_lines',data=story_lines_params, headers=headers)

        #story_lines = requests.get('https://api.mediacloud.org/api/v2/extractlines/story_lines',params=story_lines_params)
        
        preprocessed_lines = story_lines.text

        heur_extract_params = {'key':loc_key, 'preprocessed_lines':preprocessed_lines, 'story_title':title, 'story_description':description, 'extractor_method':'HeuristicExtractor'}
        heur_extract = requests.get('https://api.mediacloud.org/api/v2/extractlines/extract',params=heur_extract_params)

        crf_extract_params = {'key':loc_key, 'preprocessed_lines':preprocessed_lines, 'story_title':title, 'story_description':description, 'extractor_method':'CrfExtractor'}
        crf_extract = requests.get('https://api.mediacloud.org/api/v2/extractlines/extract',params=crf_extract_params)

        for ln, hscore in enumerate(heur_extract.json()[u'scores']):

            t = 1 if str(ln) in included_line_numbers else 0

            if hscore[u'autoexcluded'] != 1:
                h_t_ip.append( (t, hscore[u'include_probability']) )

            cscore = crf_extract.json()[u'scores'][ln]
            if u'autoexcluded' not in cscore:
                c_t_ip.append( (t, cscore[u'include_probability']) ) 
    
    except Exception as e:
        
        pass

    return h_t_ip, c_t_ip

# %%
import mediacloud, requests, csv, sys, os, json, cPickle
from pyroc import *

#extractor_training_lines_checked has the training lines for downloads for which the highest line listed as 'included' was less than the number of lines in the download (max(included_line_numbers) < len(story_lines.json()))
f = open("extractor_training_lines_checked.json").read()
reader = json.loads(f)
heur = []
cPickle.dump(heur, open("heur.p", "wb"))
crf = []
cPickle.dump(crf, open("crf.p", "wb"))
done = []
cPickle.dump(done, open("done.p", "wb"))

for row in reader[:30]:
    
    did = row[u'downloads_id']
    lns = row[u'included_line_numbers']
    
    curh, curc = gen_data(did, lns)
    
    heur+=curh
    crf+=curc
    done.append(did)
    
cPickle.dump(done, open("done.p", "wb"))
cPickle.dump(heur, open("heur.p", "wb"))
cPickle.dump(crf, open("crf.p", "wb"))

# %%
import cPickle
from pyroc import *

heur = cPickle.load(open("heur.p","rb"))
crf = cPickle.load(open("crf.p","rb"))

rocheur = ROCData(heur)
roccrf = ROCData(crf)


print rocheur.auc()

plot_multiple_roc(rocList=(rocheur,roccrf), title='Extractor ROC Curve', labels=("heuristic curve","crf curve"))
# Out:
# 0.0
