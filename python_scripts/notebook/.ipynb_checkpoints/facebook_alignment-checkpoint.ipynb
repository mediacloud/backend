# %%
import cPickle
import os.path

api_key = cPickle.load( file( os.path.expanduser( '~/mediacloud_api_key.pickle' ), 'r' ) )

# %%
##api_key = '1418b32a4e8140745240fa0b855060963c9939749bdd5562ee1b62590660b0fb'

# %%
import cPickle
import os.path

cPickle.dump( api_key, file( os.path.expanduser( '~/mediacloud_api_key.pickle' ), 'wb' ) )

# %%
import csv, pandas as pd
fb_table = pd.DataFrame.from_csv(os.path.expanduser('~/Desktop/top500.csv'))

# %%
import re, numpy as np
unmatched = []
matches = {}
match_lcs = 0
match_set = 0
sad = 0
match_split = 0
total = float(len(fb_table))
count = 0.0
for s, r in fb_table.iterrows():
    print count/total
    count += 1.0
    s = re.sub('www\.', '', s)
    print s
    #print all_media_urls_list[-1]
    if s in all_media_urls_set:
        print 'set match'
        print True
        matches[s] = s
        print
        match_set += 1

    elif s not in all_media_urls_set:
        global_longest = 0
        global_bests = {}
        for t in all_media_urls_list:
            m = len(s)
            n = len(t)
            bests = {}
            longest = 0
            lcs = np.zeros([m,n])
            for i in range(0, m):
                for j in range(0, n):
                    if s[i] == t[j]:
                        if i == 0 or 0:
                            lcs[i,j] = 1
                        else:
                            lcs[i,j] = lcs[i-1, j-1] + 1
                        if lcs[i,j] > longest:
                            bests = {j}
                            longest = lcs[i,j]
                        elif lcs[i,j] == longest:
                            bests.add(j)
                    else:
                        lcs[i,j] = 0
            #print longest
            if longest > global_longest:
                global_bests = {}
                global_bests[t] = bests
                global_longest = longest
                #print global_longest
            elif longest == global_longest:
                global_bests[t] = bests

        if global_longest == m  and len(global_bests.keys()) == 1:
            print 'lcs match'
            print True
            matches[s] = global_bests.keys()[0]
            match_lcs += 1
        
        
        
            

        else:
            not_helpful = {'org', 'net', 'com'}
            url_matched = []
            for f in re.split('\.', s):
                for k in global_bests.keys():
                    for l in re.split('\.', k):
                        if f == l and f not in not_helpful:
                            url_matched.append(k)
            if url_matched != []:
                print 'dot split match'
                print True
                match_split += 1
                
            elif len(global_bests.keys()) >= 20 and type(global_bests.keys()) == list:
                print 'too many possibles'
                print False
                sad += 1
                unmatched.append(s)
            else:
                print 'not yet categorized'
                print False
                sad += 1
                unmatched.append(s)

#             print s
#             print global_bests
#             print
        print    
print "didn't match", sad
print "matched with lcs", match_lcs
print "matched on first pass", match_set
print 'matched with splitting', match_split
# Out:
# 0.0
# readersupportednews.org
# not yet categorized
# False
#
# 0.002
# act.weareultraviolet.org
# not yet categorized
# False
#
# 0.004
# commondreams.org
# lcs match
# True
#
# 0.006
# thenewcivilrightsmovement.com
# not yet categorized
# False
#
# 0.008
# jezebel.com
# not yet categorized
# False
#
# 0.01
# ringoffireradio.com
# not yet categorized
# False
#
# 0.012
# thenation.com
# dot split match
# True
#
# 0.014
# rightwingwatch.org
# not yet categorized
# False
#
# 0.016
# liberalamerica.org
# not yet categorized
# False
#
# 0.018
# democracynow.org
# not yet categorized
# False
#
# 0.02
# advocate.com
# not yet categorized
# False
#
# 0.022
# crooksandliars.com
# set match
# True
#
# 0.024
# newnownext.com
# too many possibles
# False
#
# 0.026
# samuel-warde.com
# not yet categorized
# False
#
# 0.028
# politicususa.com
# too many possibles
# False
#
# 0.03
# alan.com
# not yet categorized
# False
#
# 0.032
# occupydemocrats.com
# not yet categorized
# False
#
# 0.034
# ...

# %%
import mediacloud, json
mc = mediacloud.api.MediaCloud(api_key)

# %%
all_media = []

last_media_id = 0

while True:
    media = mc.mediaList( last_media_id=last_media_id, rows=1000)
    #print last_media_id, len( media ), len( all_media )

    if len(media) == 0:
        break
        
    last_media_id = media[-1]['media_id']
    last_media_id
    

        
    all_media.extend(media)
    
    if len( all_media ) > 200:
       break

len(all_media)
# Out:
# 1000

# %%
print len( all_media ) 
lookup_by_url = {re.sub('www\.|http://', '', i['url']): i for i in all_media}

all_media[0]['url']
all_media_urls_set = set(lookup_by_url.keys())
all_media_urls_list = lookup_by_url.keys()
# Out:
# 1000
